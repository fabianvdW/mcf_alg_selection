# %%
from data_loader_trad import get_data
data = get_data(False)

# %%
from util import ALGO_NAMES

# %%
data
# Out:
#               g_number_of_nodes  g_number_of_arcs  g_min_cost  g_max_cost  \
# id
# GOTO_12000                 4295            148078           0        9999
# GOTO_12001                 2488             25323           0        9999
# GOTO_12002                   60               392           0        9724
# GOTO_12003                 3013            108521           0        9999
# GOTO_12004                 1416             53615           0        9999
# ...                         ...               ...         ...         ...
# NETGEN_14995               4761             70598           1       10000
# NETGEN_14996               4701            133143           1       10000
# NETGEN_14997               1696             15073           1       10000
# NETGEN_14998               3579            147603           1       10000
# NETGEN_14999               3755            176784           1       10000
#
#               g_sum_cost  g_mean_cost  g_std_cost  g_min_cap  g_max_cap  \
# id
# GOTO_12000     516631532     0.348926    0.331168          1     158554
# GOTO_12001      51254241     0.202422    0.299414          1      18538
# GOTO_12002        335220     0.087943    0.187942          1       2159
# GOTO_12003     356943084     0.328949    0.331982          1     146874
# GOTO_12004     196029312     0.365661    0.330096          1     155972
# ...                  ...          ...         ...        ...        ...
# NETGEN_14995   376228334     0.532916    0.306480          1      57299
# NETGEN_14996   689339325     0.517744    0.298414          1       3282
# NETGEN_14997    83775305     0.555797    0.313596          1      11567
# NETGEN_14998   754620042     0.511250    0.295256          1     112227
# NETGEN_14999   902652633     0.510596    0.294735          1     145749
#
#               g_sum_cap  ...  mst_mean_cost  mst_std_cost  mst_sum_cap  \
# id                       ...
# GOTO_12000    708454463  ...       0.000286      0.015258      1965224
# GOTO_12001     54255849  ...       0.000667      0.020215      1140791
# GOTO_12002       287011  ...       0.227119      0.219267        27915
# GOTO_12003    463700827  ...       0.000395      0.018217      1376375
# GOTO_12004    229448899  ...       0.000807      0.026573       625977
# ...                 ...  ...            ...           ...          ...
# NETGEN_14995  305697597  ...       0.065917      0.059557      2366528
# NETGEN_14996   79804179  ...       0.105915      0.096598      2354622
# NETGEN_14997   26289736  ...       0.151912      0.124017       858814
# NETGEN_14998  473721668  ...       0.120891      0.107873      1782318
# NETGEN_14999  633955495  ...       0.104904      0.093176      1882919
#
#               mst_mean_cap  mst_std_cap             NS           CS2  \
# id
# GOTO_12000        0.458126     0.304072  385027.000000  2.550914e+06
# GOTO_12001        0.459161     0.299933   50894.533333  2.839617e+05
# GOTO_12002        0.488776     0.255638      90.666667  3.403000e+02
# GOTO_12003        0.457421     0.306598  241958.866667  5.094957e+05
# GOTO_12004        0.442829     0.314261   94918.666667  1.974127e+05
# ...                    ...          ...            ...           ...
# NETGEN_14995      0.497170     0.290298  513117.533333  1.407012e+05
# NETGEN_14996      0.500983     0.288847  228254.500000  8.551290e+04
# NETGEN_14997      0.506675     0.289636   30247.033333  1.447840e+04
# NETGEN_14998      0.498132     0.285630  729392.666667  2.810598e+05
# NETGEN_14999      0.501577     0.287417  780566.100000  3.987534e+05
#
#                        SSP           CAS  Minimum
# id
# GOTO_12000    1.000000e+07  1.000000e+07       NS
# GOTO_12001    8.756154e+06  4.843684e+05       NS
# GOTO_12002    1.203333e+02  6.323000e+02       NS
# GOTO_12003    1.000000e+07  1.000000e+07       NS
# GOTO_12004    1.000000e+07  4.438385e+06       NS
# ...                    ...           ...      ...
# NETGEN_14995  5.704106e+06  1.000000e+07      CS2
# NETGEN_14996  7.145503e+04  1.000000e+07      SSP
# NETGEN_14997  1.085107e+05  1.238972e+06      CS2
# NETGEN_14998  1.000000e+07  1.000000e+07      CS2
# NETGEN_14999  1.000000e+07  1.000000e+07      CS2
#
# [11992 rows x 26 columns]

# %%
[(data['Minimum'] == x).sum() / len(data) for x in ALGO_NAMES]
# Out:
# [0.7472659375833556,
#  0.19988663643638305,
#  0.04122766070952254,
#  0.011619765270738864]

# %%
[((data[['GRIDGEN' in x for x in data.index]])['Minimum'] == x).sum() / 15000 for x in ALGO_NAMES]
# Out:
# [0.9990666666666667, 6.666666666666667e-05, 0.0008666666666666666, 0.0]

# %%
 [((data[['NETGEN' in x for x in data.index]])['Minimum'] == x).sum() / 15000 for x in ALGO_NAMES]
# Out:
# [0.1866, 0.7584666666666666, 0.054, 0.0]

# %%
 [((data[['GRIDGRAPH' in x for x in data.index]])['Minimum'] == x).sum() / 15000 for x in ALGO_NAMES]
# Out:
# [0.8434, 0.0, 0.11, 0.04646666666666667]

# %%
 [((data[['GOTO' in x for x in data.index]])['Minimum'] == x).sum() / 15000 for x in ALGO_NAMES]
# Out:
# [0.9592, 0.0408, 0.0, 0.0]
