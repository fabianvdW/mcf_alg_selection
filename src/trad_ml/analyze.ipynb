# %%
from data_loader_trad import get_data
data = get_data()

# %%
from util import ALGO_NAMES

# %%
data
# Out:
#               g_number_of_nodes  g_number_of_arcs  g_min_cost  g_max_cost  \
# id
# GRIDGEN_0                  4634             46307           2       19998
# GRIDGEN_1                  1297            153549           1       19996
# NETGEN_0                   1517             20167           2       10000
# GOTO_0                     3037             66080           0        9999
# GOTO_1                     4382             71126           0        9999
# ...                         ...               ...         ...         ...
# NETGEN_14928               3291             97670           1       10000
# NETGEN_14929               3513             38770           1       10000
# NETGEN_14930               1950            185526           1       10000
# NETGEN_14931                203             19075           1       10000
# NETGEN_14932               1460            161379           1       10000
#
#               g_sum_cost  g_mean_cost  g_std_cost  g_min_cap  g_max_cap  \
# id
# GRIDGEN_0      275469095     0.297468    0.230378          1     246102
# GRIDGEN_1      785765851     0.255919    0.159175          1       7408
# NETGEN_0       107608028     0.533585    0.307829          1       8547
# GOTO_0         236087079     0.357310    0.329489          1      75991
# GOTO_1         196548317     0.276366    0.324296          1      39958
# ...                  ...          ...         ...        ...        ...
# NETGEN_14928   503478812     0.515490    0.297786          1      68360
# NETGEN_14929   211192224     0.544731    0.310452          1     163323
# NETGEN_14930   938164777     0.505678    0.292110          1      58572
# NETGEN_14931    96680926     0.506846    0.291873          1      10280
# NETGEN_14932   812640848     0.503560    0.290956          1      17944
#
#               g_sum_cap  ...  mst_mean_cost  mst_std_cost  mst_sum_cap  \
# id                       ...
# GRIDGEN_0     748598320  ...       0.041255      0.036021      2549008
# GRIDGEN_1      85771356  ...       0.003395      0.027771       651986
# NETGEN_0       22294092  ...       0.148176      0.129355       759906
# GOTO_0        242573259  ...       0.000438      0.018148      1407499
# GOTO_1        192381034  ...       0.000298      0.015106      2036311
# ...                 ...  ...            ...           ...          ...
# NETGEN_14928  272223325  ...       0.093528      0.083794      1627324
# NETGEN_14929  591429469  ...       0.146756      0.132409      1759746
# NETGEN_14930  205818721  ...       0.019071      0.028104       961565
# NETGEN_14931   11513170  ...       0.198748      0.163083       105882
# NETGEN_14932  106177588  ...       0.137695      0.126347       738870
#
#               mst_mean_cap  mst_std_cap             NS            CS2  \
# id
# GRIDGEN_0         0.002236     0.014707   50372.300000  102347.200000
# GRIDGEN_1         0.067910     0.046424   23788.166667  126594.933333
# NETGEN_0          0.501257     0.289339   29277.533333   15832.100000
# GOTO_0            0.464067     0.307574  167146.566667  442724.366667
# GOTO_1            0.465270     0.304406  236673.033333  582912.300000
# ...                    ...          ...            ...            ...
# NETGEN_14928      0.494627     0.286910  354102.166667  145362.500000
# NETGEN_14929      0.501067     0.292507  369760.133333  216065.966667
# NETGEN_14930      0.493363     0.285943  237005.233333  178087.600000
# NETGEN_14931      0.529998     0.270679    3800.333333    7352.100000
# NETGEN_14932      0.506422     0.286668   82712.500000  107946.466667
#
#                        SSP           CAS  Minimum
# id
# GRIDGEN_0     2.743402e+06  5.965396e+05       NS
# GRIDGEN_1     5.228217e+05  1.944255e+05       NS
# NETGEN_0      1.008483e+05  1.779604e+06      CS2
# GOTO_0        1.000000e+07  5.196076e+06       NS
# GOTO_1        1.000000e+07  4.500574e+06       NS
# ...                    ...           ...      ...
# NETGEN_14928  5.998755e+06  1.000000e+07      CS2
# NETGEN_14929  1.000000e+07  9.199537e+06      CS2
# NETGEN_14930  5.149596e+06  1.000000e+07      CS2
# NETGEN_14931  2.192743e+04  1.001013e+06       NS
# NETGEN_14932  9.450314e+05  1.000000e+07       NS
#
# [59917 rows x 26 columns]

# %%
[(data['Minimum'] == x).sum() / len(data) for x in ALGO_NAMES]
# Out:
# [0.7472659375833556,
#  0.19988663643638305,
#  0.04122766070952254,
#  0.011619765270738864]

# %%
[((data[['GRIDGEN' in x for x in data.index]])['Minimum'] == x).sum() / 15000 for x in ALGO_NAMES]
# Out:
# [0.9990666666666667, 6.666666666666667e-05, 0.0008666666666666666, 0.0]

# %%
 [((data[['NETGEN' in x for x in data.index]])['Minimum'] == x).sum() / 15000 for x in ALGO_NAMES]
# Out:
# [0.1866, 0.7584666666666666, 0.054, 0.0]

# %%
 [((data[['GRIDGRAPH' in x for x in data.index]])['Minimum'] == x).sum() / 15000 for x in ALGO_NAMES]
# Out:
# [0.8434, 0.0, 0.11, 0.04646666666666667]

# %%
 [((data[['GOTO' in x for x in data.index]])['Minimum'] == x).sum() / 15000 for x in ALGO_NAMES]
# Out:
# [0.9592, 0.0408, 0.0, 0.0]
