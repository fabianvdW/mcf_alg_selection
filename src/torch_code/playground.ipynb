# %%
import subprocess
import torch
from torch_geometric.data import Dataset, Data
import networkx as nx
import sys

def read(instance_data):
    for line in instance_data.split("\n"):
        if line.startswith("p "):
            _, mode, n, m = line.split()
            assert mode == "min"
            g = nx.DiGraph(mode=mode)
            n = int(n)
            # if "GRIDGRAPH" in filename:
            #    k=0
            # else:
            k = 1
            nodes = list(range(k, n + k))
            g.add_nodes_from(nodes, demand=0)
        elif line.startswith("n "):
            _, ID, demand = line.split()
            g.nodes[int(ID)]["demand"] = int(demand)
        elif line.startswith("a "):
            _, src, dest, low, cap, cost = line.split()
            g.add_edge(int(src), int(dest), capacity=int(cap), weight=int(cost))
            assert int(low) == 0

    return g
# Out:
# C:\Users\Fabian\miniconda3\envs\cuda\Lib\site-packages\torch_geometric\typing.py:83: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: module 'torch_cluster' has no attribute 'knn'
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "

# %%
command = "python generate_gridgraph.py 18 30 447 10000 1000 13670324914702", ""
instance_data = subprocess.run(command[0].replace("python", sys.executable), capture_output=True, text=True, shell=True, input=command[1]).stdout
G = read(instance_data)

# %%
# %load_ext autoreload
# %autoreload 2
import torch_in_memory_loader as torch_loader
from torch_geometric.loader import DataLoader
loader = torch_loader.MCFDataset("../../data/generated_data/large_ds_parts/gen_data/merged/train")
train_loader = DataLoader(loader, batch_size=8)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Processing...
# ('"../../gridgen/gridgen"', '1 14749798765926 4646 41 1273 1680 10 246102 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 5692927417682 1299 18 555 738 124 7408 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '4188465555347 1 1517 1 1 20167 1 10000 15199 0 0 100 100 1 1000')
# ('"../../goto/goto"', '3037 72542 1000 10000 9885474938444')
# ('"../../goto/goto"', '4382 76491 1000 10000 8229282818737')
# ('"../../goto/goto"', '366 14573 1000 10000 17081967636833')
# ('python generate_gridgraph.py 41 53 913 10000 1000 9592997377759', '')
# ('"../../goto/goto"', '1399 32813 1000 10000 15482228244211')
# ('"../../goto/goto"', '2943 95569 1000 10000 10525989989873')
# ('"../../gridgen/gridgen"', '1 8553248722850 2064 24 720 493 3 140664 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 2713005877508 3467 41 1403 1628 9 211688 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '4713 111246 1000 10000 8307987370079')
# ('python generate_gridgraph.py 36 87 1684 10000 1000 9460318447504', '')
# ('"../../goto/goto"', '1230 46113 1000 10000 15443907744203')
# ('"../../gridgen/gridgen"', '1 10097268246325 3492 47 1151 251 23 24972 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '2460 74240 1000 10000 16876133731384')
# ('python generate_gridgraph.py 44 107 1743 10000 1000 13185857803758', '')
# ('"../../goto/goto"', '1577 163820 1000 10000 10436179276941')
# ('"../../goto/goto"', '977 42230 1000 10000 9886596846404')
# ('"../../gridgen/gridgen"', '1 2450719113091 3355 28 3128 42 34 238625 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '7605701697638 1 1480 1 1 86027 1 10000 97112 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 29 45 162 10000 1000 11085888917495', '')
# ('"../../gridgen/gridgen"', '1 8518347073837 4329 35 1460 1243 2 163793 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 16454401684498 661 10 358 293 8 19002 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '17237305986155 1 528 1 1 13532 1 10000 34473 0 0 100 100 1 1000')
# ('"../../netgen/netgen"', '13644099522984 1 1071 1 1 97434 1 10000 53875 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 38 47 1721 10000 1000 77250566619', '')
# ('"../../gridgen/gridgen"', '1 7085467751258 951 23 141 397 208 25879 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '1518 39555 1000 10000 668220761411')
# ('python generate_gridgraph.py 19 98 45 10000 1000 11189051507411', '')
# ('"../../gridgen/gridgen"', '1 9915163527398 3298 15 1468 1528 30 201510 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '3961 135888 1000 10000 16879448015351')
# ('"../../gridgen/gridgen"', '1 1840537853602 4791 28 2463 759 21 407513 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '4261445467456 1 4090 1 1 83060 1 10000 253086 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 2515609941366 4469 65 2927 1281 7 62192 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 266837360727 4399 48 741 2109 18 226956 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 33 34 1281 10000 1000 8440365332950', '')
# ('python generate_gridgraph.py 8 69 446 10000 1000 10729438544423', '')
# ('"../../goto/goto"', '1376 138726 1000 10000 5714526417491')
# ('"../../goto/goto"', '3405 57092 1000 10000 9416545803893')
# ('"../../goto/goto"', '967 7010 1000 10000 7585630779617')
# ('"../../goto/goto"', '3336 197792 1000 10000 12011481040538')
# ('"../../gridgen/gridgen"', '1 3245439599046 1479 36 530 798 82 94221 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 38 90 359 10000 1000 15428305850936', '')
# ('"../../goto/goto"', '1748 14783 1000 10000 6231062772902')
# ('"../../goto/goto"', '2861 153299 1000 10000 8776597001529')
# ('"../../goto/goto"', '4325 126044 1000 10000 14967141952627')
# ('"../../gridgen/gridgen"', '1 10201312481864 4996 49 1533 1772 32 388528 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '2463 90691 1000 10000 8575026731548')
# ('"../../goto/goto"', '4582 130989 1000 10000 5517684379841')
# ('"../../netgen/netgen"', '4475890052579 1 4611 1 1 178950 1 10000 53476 0 0 100 100 1 1000')
# ('"../../goto/goto"', '3464 176079 1000 10000 16351005371460')
# ('"../../gridgen/gridgen"', '1 7452262660600 1656 36 269 620 85 14046 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 12328223070840 1364 12 214 460 123 25858 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '2233 79745 1000 10000 12271081008318')
# ('"../../gridgen/gridgen"', '1 7322880338231 2622 21 916 647 19 228340 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '6965730347770 1 2113 1 1 9856 1 10000 98857 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 24 64 1049 10000 1000 478095129825', '')
# ('"../../netgen/netgen"', '8964900892970 1 4976 1 1 79833 1 10000 27538 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 4615520553355 4235 23 2239 701 42 298262 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 12630477839941 2492 22 1234 296 26 220801 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 51 55 135 10000 1000 10021475435829', '')
# ('"../../goto/goto"', '3100 65956 1000 10000 15587629890086')
# ('"../../goto/goto"', '2814 109129 1000 10000 1489971735536')
# ('"../../goto/goto"', '1876 194240 1000 10000 8184432458814')
# ('"../../goto/goto"', '4737 51893 1000 10000 261369042162')
# ('"../../gridgen/gridgen"', '1 7161377768257 4828 6 226 4242 34 426234 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 48 63 1634 10000 1000 14408604833588', '')
# ('python generate_gridgraph.py 42 42 762 10000 1000 14175732868192', '')
# ('python generate_gridgraph.py 43 93 1205 10000 1000 3968101489207', '')
# ('"../../netgen/netgen"', '17261366218831 1 2639 1 1 196377 1 10000 99689 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 11336245113623 4684 32 1691 1776 12 365541 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 16 193 47 10000 1000 11347473953046', '')
# ('"../../netgen/netgen"', '8238628278776 1 3696 1 1 29443 1 10000 211409 0 0 100 100 1 1000')
# ('"../../netgen/netgen"', '16956339696940 1 3824 1 1 30606 1 10000 147240 0 0 100 100 1 1000')
# ('"../../netgen/netgen"', '8055129378356 1 2617 1 1 177996 1 10000 191699 0 0 100 100 1 1000')
# ('"../../goto/goto"', '3127 139605 1000 10000 3302270463277')
# ('"../../goto/goto"', '3694 170157 1000 10000 12894835761883')
# ('python generate_gridgraph.py 53 67 724 10000 1000 4410762242971', '')
# ('"../../gridgen/gridgen"', '1 14750397151399 689 13 490 172 167 61904 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 1387844431874 815 13 428 166 121 18084 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 23 75 1959 10000 1000 4877489463518', '')
# ('"../../gridgen/gridgen"', '1 2592486904043 3437 26 1577 374 30 246735 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '986 87842 1000 10000 12869004264652')
# ('"../../netgen/netgen"', '1876541117567 1 2924 1 1 71925 1 10000 148970 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 17064232301835 2658 5 1096 1167 67 56383 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '3521 24236 1000 10000 5214957227891')
# ('python generate_gridgraph.py 41 77 495 10000 1000 12876588834850', '')
# ('"../../gridgen/gridgen"', '1 788060910370 3160 25 1278 715 48 56358 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 14965263264218 1460 36 598 476 131 83564 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '4365140057868 1 4712 1 1 123303 1 10000 422960 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 12584119728280 3507 49 1238 1533 48 30630 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 3874618981881 564 22 201 154 345 32517 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 44 64 617 10000 1000 8488144939171', '')
# ('python generate_gridgraph.py 21 46 34 10000 1000 15480121392196', '')
# ('"../../gridgen/gridgen"', '1 9983359927192 4054 49 497 1541 19 243175 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '4816 148332 1000 10000 15417256322746')
# ('"../../gridgen/gridgen"', '1 6253084149875 1094 25 685 225 100 83276 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 4409612593806 2650 51 18 1610 73 155203 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 15813285948093 4881 54 1005 3293 21 291604 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 14716145006536 4396 21 1391 658 2 278647 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '5480724812115 1 4168 1 1 98943 1 10000 300985 0 0 100 100 1 1000')
# ('"../../goto/goto"', '1294 68207 1000 10000 571187700058')
# ('"../../gridgen/gridgen"', '1 9694877487240 2182 42 33 1097 7 28611 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 36 124 1732 10000 1000 5055262196618', '')
# ('"../../goto/goto"', '2070 140059 1000 10000 4924398092115')
# ('"../../netgen/netgen"', '9302508886498 1 1594 1 1 183608 1 10000 6661 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 50 65 1106 10000 1000 10034786172581', '')
# ('"../../goto/goto"', '3674 140714 1000 10000 10910707193893')
# ('"../../gridgen/gridgen"', '1 12504908694691 1829 35 264 360 13 57173 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '1093 60205 1000 10000 7331058987723')
# ('"../../netgen/netgen"', '16401993728043 1 1990 1 1 66130 1 10000 30900 0 0 100 100 1 1000')
# ('"../../goto/goto"', '222 7520 1000 10000 514663859535')
# ('"../../gridgen/gridgen"', '1 585880957276 2968 43 1173 927 58 197675 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 17231441581406 4458 47 1382 1941 19 368344 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 2162058186635 1957 17 867 549 4 153642 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '15726906389638 1 3699 1 1 45254 1 10000 74680 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 5919533490909 834 26 337 245 54 42396 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 26 71 1227 10000 1000 3060441520136', '')
# ('"../../gridgen/gridgen"', '1 12509545561349 2438 37 975 873 12 102632 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '2596 36529 1000 10000 10469063233702')
# ('"../../netgen/netgen"', '161564455782 1 2815 1 1 76697 1 10000 244819 0 0 100 100 1 1000')
# ('"../../netgen/netgen"', '13518791818901 1 425 1 1 62967 1 10000 10163 0 0 100 100 1 1000')
# ('"../../goto/goto"', '3733 103260 1000 10000 13676349669795')
# ('"../../gridgen/gridgen"', '1 2476068467782 1650 21 610 70 63 75519 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '11366368895805 1 4574 1 1 94043 1 10000 340974 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 13677612621685 3589 19 1995 915 52 89020 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '4976 132671 1000 10000 12242819714685')
# ('python generate_gridgraph.py 58 58 771 10000 1000 3711596393807', '')
# ('python generate_gridgraph.py 17 45 1441 10000 1000 5448358095672', '')
# ('"../../goto/goto"', '3832 162584 1000 10000 4658361717335')
# ('"../../goto/goto"', '4773 149826 1000 10000 1395764213637')
# ('"../../gridgen/gridgen"', '1 17152819222511 2005 27 200 1098 50 163975 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '4534 33862 1000 10000 17037651023115')
# ('"../../netgen/netgen"', '12231519964220 1 3488 1 1 117827 1 10000 253862 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 3791664089750 2429 8 407 1835 65 159813 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 4766191246065 775 22 415 29 223 56648 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '2211 149356 1000 10000 15259010554935')
# ('python generate_gridgraph.py 37 97 1769 10000 1000 420114529684', '')
# ('"../../netgen/netgen"', '15744033278938 1 217 1 1 31892 1 10000 11381 0 0 100 100 1 1000')
# ('"../../netgen/netgen"', '5348400194079 1 290 1 1 73636 1 10000 17277 0 0 100 100 1 1000')
# ('"../../netgen/netgen"', '12095064067036 1 789 1 1 199517 1 10000 27516 0 0 100 100 1 1000')
# ('"../../goto/goto"', '1995 175745 1000 10000 3779339513322')
# ('python generate_gridgraph.py 21 208 524 10000 1000 1929240445988', '')
# ('"../../gridgen/gridgen"', '1 14199231058390 1234 12 531 641 38 13624 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '2724 172212 1000 10000 13011864409982')
# ('python generate_gridgraph.py 17 19 1809 10000 1000 4921296821418', '')
# ('"../../goto/goto"', '4525 95276 1000 10000 13163850992121')
# ('"../../gridgen/gridgen"', '1 2517814371844 1977 34 448 688 55 187056 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '16677751545270 1 3527 1 1 162405 1 10000 177687 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 9633500459567 4036 23 1691 1581 43 191748 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 8504142940170 1931 27 585 605 48 132106 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 14792956968354 4113 22 853 2134 17 382632 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 15380598865954 1580 25 396 465 64 115453 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '903044874301 1 2656 1 1 95173 1 10000 236682 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 64 67 1611 10000 1000 12117446770012', '')
# ('"../../gridgen/gridgen"', '1 7280784036708 4930 7 781 5 21 135244 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 7442975601767 1733 34 216 1315 43 80144 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 27 70 1165 10000 1000 15155906947947', '')
# ('python generate_gridgraph.py 32 155 1711 10000 1000 7795725326966', '')
# ('"../../goto/goto"', '3012 78370 1000 10000 10789224085963')
# ('"../../netgen/netgen"', '6822821341645 1 3916 1 1 112545 1 10000 3172 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 1456779696383 369 6 112 127 104 8813 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 6128033791562 1777 11 291 993 37 42637 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '1191 112030 1000 10000 15155521218168')
# ('"../../goto/goto"', '1649 75844 1000 10000 8398463493905')
# ('"../../goto/goto"', '3910 84492 1000 10000 11735638343227')
# ('"../../gridgen/gridgen"', '1 12226253426220 3707 56 1045 1488 5 36351 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 1737250871209 4192 15 1468 1332 13 3888 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 13595790418779 2532 37 1348 231 63 99723 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 47 81 407 10000 1000 12100393143920', '')
# ('python generate_gridgraph.py 13 96 93 10000 1000 4632540314799', '')
# ('python generate_gridgraph.py 26 190 809 10000 1000 12011554955454', '')
# ('python generate_gridgraph.py 34 50 1 10000 1000 11006689129230', '')
# ('"../../gridgen/gridgen"', '1 13456260226686 2393 13 949 1087 45 25932 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 39 88 1368 10000 1000 6103586417351', '')
# ('python generate_gridgraph.py 40 63 1655 10000 1000 2304891221295', '')
# ('"../../gridgen/gridgen"', '1 7250574209641 1749 19 122 1021 61 64061 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '13557928988628 1 4991 1 1 153789 1 10000 303559 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 35 53 794 10000 1000 4522014819406', '')
# ('python generate_gridgraph.py 13 18 1258 10000 1000 3692934625441', '')
# ('python generate_gridgraph.py 40 65 564 10000 1000 14313514985100', '')
# ('python generate_gridgraph.py 36 48 912 10000 1000 8595866837195', '')
# ('"../../goto/goto"', '4108 27957 1000 10000 3719037049242')
# ('"../../netgen/netgen"', '14817406817384 1 263 1 1 10806 1 10000 17280 0 0 100 100 1 1000')
# ('"../../goto/goto"', '3958 170625 1000 10000 8096638733951')
# ('"../../gridgen/gridgen"', '1 10077728926501 4662 59 2688 277 4 332500 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '3600 106703 1000 10000 13806878149626')
# ('"../../goto/goto"', '1371 82816 1000 10000 14701871016515')
# ('"../../netgen/netgen"', '15480187676347 1 2343 1 1 80981 1 10000 4169 0 0 100 100 1 1000')
# ('"../../goto/goto"', '3449 68783 1000 10000 6923850989011')
# ('"../../goto/goto"', '3695 150535 1000 10000 16865875264433')
# ('python generate_gridgraph.py 36 64 140 10000 1000 2886444898613', '')
# ('"../../gridgen/gridgen"', '1 4921055040701 2209 20 1174 1 89 103548 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '4003 135724 1000 10000 9853228966734')
# ('"../../netgen/netgen"', '11818429625038 1 4403 1 1 167757 1 10000 400003 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 8254253846780 3125 39 1152 1345 53 103624 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 3872297983748 1782 5 468 134 20 56451 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 2900924980273 4299 59 3293 717 28 364075 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '12787391914035 1 122 1 1 11856 1 10000 3101 0 0 100 100 1 1000')
# ('"../../goto/goto"', '3615 188108 1000 10000 16544939298245')
# ('"../../netgen/netgen"', '14150269694277 1 4731 1 1 15582 1 10000 43886 0 0 100 100 1 1000')
# ('"../../goto/goto"', '4802 156137 1000 10000 11852686553011')
# ('"../../gridgen/gridgen"', '1 11899159721355 1037 9 479 45 161 45748 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '720 10009 1000 10000 6610133313542')
# ('python generate_gridgraph.py 19 48 1369 10000 1000 13818365570785', '')
# ('"../../goto/goto"', '2721 84314 1000 10000 772805587328')
# ('"../../gridgen/gridgen"', '1 711341923120 4057 11 2793 265 22 206999 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 8770869767249 4590 29 1692 586 33 106394 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '523 17023 1000 10000 12795981208994')
# ('python generate_gridgraph.py 36 40 1460 10000 1000 1632746653839', '')
# ('"../../gridgen/gridgen"', '1 5904914407937 3031 22 124 621 15 78814 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 61 70 1771 10000 1000 9139447765218', '')
# ('python generate_gridgraph.py 17 22 1135 10000 1000 15765691888563', '')
# ('"../../netgen/netgen"', '2289509928025 1 1120 1 1 176703 1 10000 30732 0 0 100 100 1 1000')
# ('"../../netgen/netgen"', '15483642294016 1 2777 1 1 187985 1 10000 111066 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 32 101 303 10000 1000 16559215293227', '')
# ('python generate_gridgraph.py 9 65 454 10000 1000 2281109694021', '')
# ('"../../gridgen/gridgen"', '1 17216841975001 1184 34 559 43 57 87143 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '1308231097181 1 4975 1 1 41542 1 10000 302633 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 37 43 1043 10000 1000 333093176105', '')
# ('"../../gridgen/gridgen"', '1 6525078242663 189 11 60 45 178 17029 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 39 85 382 10000 1000 1696210347784', '')
# ('"../../gridgen/gridgen"', '1 13927817418406 233 9 111 26 106 20746 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 60 71 1863 10000 1000 650030660065', '')
# ('"../../gridgen/gridgen"', '1 12519260810313 2436 5 687 650 66 70222 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '1875 92465 1000 10000 2614364982219')
# ('python generate_gridgraph.py 55 59 1998 10000 1000 6301801504788', '')
# ('"../../goto/goto"', '3430 122881 1000 10000 15170158937745')
# ('python generate_gridgraph.py 24 126 313 10000 1000 11643951604022', '')
# ('"../../goto/goto"', '104 1409 1000 10000 7044047221167')
# ('"../../gridgen/gridgen"', '1 11650050012474 4892 60 811 1828 6 160493 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 67 72 1668 10000 1000 15608421532409', '')
# ('"../../goto/goto"', '1200 131186 1000 10000 15270305612691')
# ('"../../goto/goto"', '2248 82593 1000 10000 5792866214678')
# ('python generate_gridgraph.py 36 87 1303 10000 1000 17104284585346', '')
# ('"../../gridgen/gridgen"', '1 2066859734834 844 15 375 76 155 41110 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 37 134 522 10000 1000 12854284554513', '')
# ('"../../gridgen/gridgen"', '1 3219712352022 3417 35 838 922 31 241129 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '1373164409279 1 4753 1 1 109213 1 10000 293922 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 38 63 869 10000 1000 14292711968148', '')
# ('"../../gridgen/gridgen"', '1 3410726230757 4361 28 2760 1361 12 260183 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '2120 95062 1000 10000 5384453690869')
# ('"../../gridgen/gridgen"', '1 9712228702218 3090 7 1088 1207 32 288451 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '12645396813711 1 134 1 1 1252 1 10000 10948 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 25 39 1868 10000 1000 8539772753877', '')
# ('python generate_gridgraph.py 47 97 707 10000 1000 14720886086054', '')
# ('"../../netgen/netgen"', '10927072150390 1 72 1 1 3813 1 10000 764 0 0 100 100 1 1000')
# ('"../../goto/goto"', '4249 137632 1000 10000 13084179784976')
# ('"../../goto/goto"', '436 12639 1000 10000 8046247307672')
# ('"../../gridgen/gridgen"', '1 16931510302932 4850 12 1841 1287 12 449068 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 13 17 31 10000 1000 12036001117257', '')
# ('"../../gridgen/gridgen"', '1 240950596373 2758 32 419 811 16 72571 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '15848662650778 1 2486 1 1 181110 1 10000 168318 0 0 100 100 1 1000')
# ('"../../netgen/netgen"', '7348722453513 1 2529 1 1 173885 1 10000 88117 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 37 130 1587 10000 1000 6620993097374', '')
# ('"../../gridgen/gridgen"', '1 9535617292246 1523 9 471 554 40 138669 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '2534 45684 1000 10000 15909199510951')
# ('"../../goto/goto"', '4946 52246 1000 10000 13925912025847')
# ('"../../gridgen/gridgen"', '1 14030467985677 2972 46 1957 472 4 20910 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 46 84 906 10000 1000 10567533386028', '')
# ('python generate_gridgraph.py 26 180 291 10000 1000 9304407882132', '')
# ('python generate_gridgraph.py 26 85 748 10000 1000 9223876251772', '')
# ('"../../goto/goto"', '1703 53268 1000 10000 11901345499467')
# ('"../../netgen/netgen"', '98015396116 1 4245 1 1 28054 1 10000 270249 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 52 73 746 10000 1000 13231628002248', '')
# ('"../../gridgen/gridgen"', '1 13802488116023 2606 43 1094 1507 44 26090 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 15988203418692 957 19 392 152 61 36234 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 2419271635170 3477 16 1500 590 30 154971 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '1378 50617 1000 10000 9798588211169')
# ('"../../gridgen/gridgen"', '1 12169090187050 1476 30 1422 10 33 132713 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '4885276224075 1 3885 1 1 8263 1 10000 256299 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 1035590845231 2614 31 568 1164 40 204293 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 15544300712370 2304 20 171 1131 6 70149 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 11871371550971 4329 10 555 1327 44 140238 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 12 12 960 10000 1000 5097138509160', '')
# ('"../../goto/goto"', '492 11761 1000 10000 14802246432040')
# ('"../../netgen/netgen"', '1568235322485 1 4905 1 1 164691 1 10000 298645 0 0 100 100 1 1000')
# ('"../../goto/goto"', '4243 157498 1000 10000 15573062021208')
# ('"../../goto/goto"', '3596 138247 1000 10000 11434074253320')
# ('python generate_gridgraph.py 48 97 77 10000 1000 12162917026317', '')
# ('python generate_gridgraph.py 30 64 1763 10000 1000 16901165905412', '')
# ('"../../netgen/netgen"', '14662819140691 1 1080 1 1 73192 1 10000 82907 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 3380777653639 4977 21 2665 1096 28 187579 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '2371 35042 1000 10000 14746767996206')
# ('python generate_gridgraph.py 33 81 1052 10000 1000 9722912449496', '')
# ('python generate_gridgraph.py 20 25 830 10000 1000 11137194590048', '')
# ('"../../goto/goto"', '2963 33998 1000 10000 15095580323812')
# ('"../../goto/goto"', '3519 189247 1000 10000 13697120379245')
# ('"../../goto/goto"', '1315 101724 1000 10000 7645611675078')
# ('"../../gridgen/gridgen"', '1 13435976547459 1379 37 570 414 117 57254 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 5822391705000 2048 42 1399 536 22 124193 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '2540825359780 1 4163 1 1 67417 1 10000 259198 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 35 119 1916 10000 1000 3411355793184', '')
# ('"../../gridgen/gridgen"', '1 14533625007749 4862 45 987 3614 3 328922 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 7 539 61 10000 1000 5638763289844', '')
# ('"../../gridgen/gridgen"', '1 15170921198546 1771 12 450 912 46 153949 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '7356513461874 1 1496 1 1 11431 1 10000 89689 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 15538087052958 1115 24 653 359 144 59574 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '1802 22821 1000 10000 16328461778364')
# ('python generate_gridgraph.py 34 78 1158 10000 1000 5218020286269', '')
# ('"../../goto/goto"', '3618 128969 1000 10000 5414879691098')
# ('"../../netgen/netgen"', '9746282445761 1 1492 1 1 183337 1 10000 84476 0 0 100 100 1 1000')
# ('"../../goto/goto"', '1317 127889 1000 10000 9322175812238')
# ('"../../gridgen/gridgen"', '1 10550510596150 689 8 180 462 84 14913 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 5295747388739 220 12 94 55 44 20109 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '4337148043057 1 4848 1 1 117617 1 10000 410413 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 13778392758516 2273 42 965 948 34 880 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 16269839845846 4698 58 1910 1681 28 370786 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '3485 137195 1000 10000 16573560386474')
# ('"../../gridgen/gridgen"', '1 16795184533235 1344 32 68 838 12 80247 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '3181 124011 1000 10000 5639910234865')
# ('"../../goto/goto"', '2257 85340 1000 10000 12921446637426')
# ('"../../goto/goto"', '747 42902 1000 10000 9014942421786')
# ('"../../gridgen/gridgen"', '1 3391456764131 1896 31 555 909 28 64594 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 11455069375990 3314 45 1047 68 29 102787 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 17 22 1462 10000 1000 15939770665808', '')
# ('"../../gridgen/gridgen"', '1 8696007554640 368 8 119 152 15 29359 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 617825165028 2691 49 1226 656 34 220575 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 14 61 1 10000 1000 14604415308721', '')
# ('"../../netgen/netgen"', '3632869109289 1 4299 1 1 131165 1 10000 214292 0 0 100 100 1 1000')
# ('python generate_gridgraph.py 42 70 1770 10000 1000 15643240671331', '')
# ('"../../gridgen/gridgen"', '1 11637927718521 1418 28 439 932 12 132702 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 3282126743535 3941 32 1912 1313 46 258449 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 32 150 166 10000 1000 2860829763976', '')
# ('"../../goto/goto"', '590 30707 1000 10000 12763299963677')
# ('"../../gridgen/gridgen"', '1 191873694984 466 13 210 68 3 4173 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 32 38 1531 10000 1000 12180551870869', '')
# ('"../../goto/goto"', '1754 120701 1000 10000 15512970398511')
# ('"../../goto/goto"', '183 1478 1000 10000 7564618276755')
# ('"../../netgen/netgen"', '11549446584595 1 34 1 1 148 1 10000 3332 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 13141915754493 4729 16 500 1506 4 118271 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 33 69 776 10000 1000 912889950257', '')
# ('python generate_gridgraph.py 53 84 1990 10000 1000 12591921739607', '')
# ('"../../netgen/netgen"', '11443418141340 1 2482 1 1 99850 1 10000 111671 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 10370411398438 4367 18 422 1380 23 291864 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 24 75 1769 10000 1000 9177061813550', '')
# ('python generate_gridgraph.py 19 31 915 10000 1000 9996074318554', '')
# ('"../../gridgen/gridgen"', '1 11028838347265 2403 23 870 428 18 237080 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 6829718853178 4275 7 266 1549 11 347677 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 35 108 1835 10000 1000 16408375409460', '')
# ('python generate_gridgraph.py 62 76 220 10000 1000 5111631990760', '')
# ('"../../goto/goto"', '2728 92585 1000 10000 11911290068697')
# ('"../../goto/goto"', '772 27361 1000 10000 14931535377366')
# ('"../../gridgen/gridgen"', '1 7713840199043 4081 25 627 1981 4 201870 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '383 3016 1000 10000 1916911965063')
# ('"../../goto/goto"', '4019 78043 1000 10000 7505682741888')
# ('python generate_gridgraph.py 8 69 245 10000 1000 12364182050901', '')
# ('"../../goto/goto"', '1931 120696 1000 10000 1326446302907')
# ('"../../goto/goto"', '3250 106514 1000 10000 16995655153407')
# ('python generate_gridgraph.py 36 77 1598 10000 1000 7699928755220', '')
# ('python generate_gridgraph.py 23 25 1331 10000 1000 14497866511723', '')
# ('"../../goto/goto"', '4177 167346 1000 10000 4834151530749')
# ('python generate_gridgraph.py 20 130 550 10000 1000 14091220267530', '')
# ('"../../gridgen/gridgen"', '1 6777818370948 4490 5 2329 240 24 150227 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 11075866615201 4643 35 1250 1393 10 425973 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 43 54 683 10000 1000 389208758247', '')
# ('"../../goto/goto"', '4432 170053 1000 10000 10486628492092')
# ('python generate_gridgraph.py 54 75 1177 10000 1000 15149796572077', '')
# ('python generate_gridgraph.py 39 45 428 10000 1000 12408080004860', '')
# ('"../../goto/goto"', '741 14471 1000 10000 2254838028493')
# ('"../../goto/goto"', '2060 123658 1000 10000 12600794625468')
# ('"../../netgen/netgen"', '11850656501879 1 4235 1 1 139071 1 10000 71307 0 0 100 100 1 1000')
# ('"../../gridgen/gridgen"', '1 15550001038066 1801 20 283 577 90 171977 1 1 10000 1 1 1000')
# ('python generate_gridgraph.py 59 68 780 10000 1000 8616443567300', '')
# ('"../../goto/goto"', '1192 126520 1000 10000 11167803598597')
# ('"../../gridgen/gridgen"', '1 10837175783194 3055 23 396 2096 62 228631 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '1215 108332 1000 10000 10459523691616')
# ('python generate_gridgraph.py 60 76 1483 10000 1000 12502972887766', '')
# ('"../../gridgen/gridgen"', '1 14320118218816 81 7 36 1 39 2104 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 4543041583948 496 16 99 246 105 23454 1 1 10000 1 1 1000')
# ('"../../netgen/netgen"', '14987831639011 1 3887 1 1 88170 1 10000 53241 0 0 100 100 1 1000')
# ('"../../goto/goto"', '806 28526 1000 10000 6632422573706')
# ('"../../goto/goto"', '2310 147715 1000 10000 4986741989825')
# ('"../../gridgen/gridgen"', '1 14247468106261 1783 23 625 530 39 108087 1 1 10000 1 1 1000')
# ('"../../gridgen/gridgen"', '1 3781393352770 2822 39 1599 365 7 34520 1 1 10000 1 1 1000')
# ('"../../goto/goto"', '739 29127 1000 10000 3594189365259')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       3 import torch_in_memory_loader as torch_loader
#       4 from torch_geometric.loader import DataLoader
# ----> 5 loader = torch_loader.MCFDataset("../../data/generated_data/large_ds_parts/gen_data/merged")
#       6 train_loader = DataLoader(loader, batch_size=8)
#
# File C:\cygwin64\home\Fabian\mcf_alg_selection\src\torch_code\torch_in_memory_loader.py:63, in MCFDataset.__init__(self, root, transform)
#      61             self.idx_to_id.append(id)
#      62             self.id_to_cmd[id] = ast.literal_eval(command)
# ---> 63 super().__init__(root, transform)
#      64 self._indices = list(range(len(self.idx_to_id)))
#
# File ~\miniconda3\envs\cuda\Lib\site-packages\torch_geometric\data\dataset.py:115, in Dataset.__init__(self, root, transform, pre_transform, pre_filter, log, force_reload)
#     112     self._download()
#     114 if self.has_process:
# --> 115     self._process()
#
# File ~\miniconda3\envs\cuda\Lib\site-packages\torch_geometric\data\dataset.py:260, in Dataset._process(self)
#     257     print('Processing...', file=sys.stderr)
#     259 fs.makedirs(self.processed_dir, exist_ok=True)
# --> 260 self.process()
#     262 path = osp.join(self.processed_dir, 'pre_transform.pt')
#     263 fs.torch_save(_repr(self.pre_transform), path)
#
# File C:\cygwin64\home\Fabian\mcf_alg_selection\src\torch_code\torch_in_memory_loader.py:102, in MCFDataset.process(self)
#     100         data_dict["edge_index"][1, edge_num] = mapping[int(dst)]
#     101         data_dict["capacity"].append(float(cap))
# --> 102         data_dict["weight"].append(float(cost))
#     103         edge_num += 1
#     104 data_dict["label"] = self.id_to_runtime[graph_id]
#
# KeyboardInterrupt:

# %%
from torch_code.gin import GIN
model = GIN(device="cpu", in_channels=1, hidden_channels=32, out_channels=4, num_gin_layers=4, num_mlp_layers=2, num_mlp_readout_layers=2, skip_connections=True)

# %%
import torch.nn.functional as F
F.cross_entropy(model_out, first_batch.y)
# Out:
# tensor(1.8374, grad_fn=<NllLossBackward0>)

# %%
# Out:
# tensor([[0.2025, 0.1708, 0.1369, 0.4898],
#         [0.1516, 0.1642, 0.1220, 0.5622],
#         [0.0935, 0.3766, 0.1913, 0.3387],
#         [0.4254, 0.2069, 0.1421, 0.2257],
#         [0.0173, 0.2131, 0.4295, 0.3401],
#         [0.3777, 0.2017, 0.0494, 0.3712],
#         [0.2203, 0.0934, 0.3069, 0.3794],
#         [0.4843, 0.0538, 0.4521, 0.0098]], grad_fn=<SoftmaxBackward0>)

# %%
import time
import numpy as np
now = time.time()
nodes = []
edges = []
ys = []
runtimes = []
graphs = []
for i in range(len(loader)):
    graph_i = loader.get(i)
    graphs.append(graph_i)
    print(f"{i}", graph_i)
    nodes.append(graph_i.num_nodes)
    edges.append(graph_i.edge_attr.shape[0])
    ys.append(graph_i.y)
    runtimes.append(graph_i.label)

print(time.time() - now)
print(f"Avg. nodes {np.mean(nodes)}")
print(f"Avg. edges {np.mean(edges)}")
# Out:
# 0 Data(edge_index=[2, 125152], y=0, label=[1, 4], num_nodes=3911, x=[3911, 1], edge_attr=[125152, 2])
# 1 Data(edge_index=[2, 2984], y=0, label=[1, 4], num_nodes=1510, x=[1510, 1], edge_attr=[2984, 2])
# 2 Data(edge_index=[2, 45359], y=0, label=[1, 4], num_nodes=2276, x=[2276, 1], edge_attr=[45359, 2])
# 3 Data(edge_index=[2, 100777], y=1, label=[1, 4], num_nodes=2870, x=[2870, 1], edge_attr=[100777, 2])
# 4 Data(edge_index=[2, 14700], y=0, label=[1, 4], num_nodes=1225, x=[1225, 1], edge_attr=[14700, 2])
# 5 Data(edge_index=[2, 101035], y=0, label=[1, 4], num_nodes=3559, x=[3559, 1], edge_attr=[101035, 2])
# 6 Data(edge_index=[2, 26388], y=0, label=[1, 4], num_nodes=2199, x=[2199, 1], edge_attr=[26388, 2])
# 7 Data(edge_index=[2, 105145], y=0, label=[1, 4], num_nodes=3369, x=[3369, 1], edge_attr=[105145, 2])
# 8 Data(edge_index=[2, 48182], y=0, label=[1, 4], num_nodes=1267, x=[1267, 1], edge_attr=[48182, 2])
# 9 Data(edge_index=[2, 163248], y=0, label=[1, 4], num_nodes=3401, x=[3401, 1], edge_attr=[163248, 2])
# 10 Data(edge_index=[2, 61875], y=0, label=[1, 4], num_nodes=375, x=[375, 1], edge_attr=[61875, 2])
# 11 Data(edge_index=[2, 9364], y=3, label=[1, 4], num_nodes=4745, x=[4745, 1], edge_attr=[9364, 2])
# 12 Data(edge_index=[2, 164965], y=1, label=[1, 4], num_nodes=2933, x=[2933, 1], edge_attr=[164965, 2])
# 13 Data(edge_index=[2, 123101], y=0, label=[1, 4], num_nodes=3971, x=[3971, 1], edge_attr=[123101, 2])
# 14 Data(edge_index=[2, 13894], y=1, label=[1, 4], num_nodes=1227, x=[1227, 1], edge_attr=[13894, 2])
# 15 Data(edge_index=[2, 119423], y=0, label=[1, 4], num_nodes=2058, x=[2058, 1], edge_attr=[119423, 2])
# 16 Data(edge_index=[2, 100781], y=0, label=[1, 4], num_nodes=1998, x=[1998, 1], edge_attr=[100781, 2])
# 17 Data(edge_index=[2, 20815], y=0, label=[1, 4], num_nodes=4651, x=[4651, 1], edge_attr=[20815, 2])
# 18 Data(edge_index=[2, 146015], y=1, label=[1, 4], num_nodes=2909, x=[2909, 1], edge_attr=[146015, 2])
# 19 Data(edge_index=[2, 64425], y=0, label=[1, 4], num_nodes=773, x=[773, 1], edge_attr=[64425, 2])
# 20 Data(edge_index=[2, 7775], y=0, label=[1, 4], num_nodes=426, x=[426, 1], edge_attr=[7775, 2])
# 21 Data(edge_index=[2, 80928], y=0, label=[1, 4], num_nodes=2725, x=[2725, 1], edge_attr=[80928, 2])
# 22 Data(edge_index=[2, 7762], y=2, label=[1, 4], num_nodes=3962, x=[3962, 1], edge_attr=[7762, 2])
# 23 Data(edge_index=[2, 141669], y=0, label=[1, 4], num_nodes=4293, x=[4293, 1], edge_attr=[141669, 2])
# 24 Data(edge_index=[2, 173976], y=0, label=[1, 4], num_nodes=659, x=[659, 1], edge_attr=[173976, 2])
# 25 Data(edge_index=[2, 132848], y=0, label=[1, 4], num_nodes=1444, x=[1444, 1], edge_attr=[132848, 2])
# 26 Data(edge_index=[2, 80000], y=1, label=[1, 4], num_nodes=1473, x=[1473, 1], edge_attr=[80000, 2])
# 27 Data(edge_index=[2, 39366], y=0, label=[1, 4], num_nodes=596, x=[596, 1], edge_attr=[39366, 2])
# 28 Data(edge_index=[2, 120260], y=0, label=[1, 4], num_nodes=982, x=[982, 1], edge_attr=[120260, 2])
# 29 Data(edge_index=[2, 5228], y=0, label=[1, 4], num_nodes=2669, x=[2669, 1], edge_attr=[5228, 2])
# 30 Data(edge_index=[2, 122669], y=0, label=[1, 4], num_nodes=3678, x=[3678, 1], edge_attr=[122669, 2])
# 31 Data(edge_index=[2, 8213], y=0, label=[1, 4], num_nodes=4144, x=[4144, 1], edge_attr=[8213, 2])
# 32 Data(edge_index=[2, 162334], y=0, label=[1, 4], num_nodes=3529, x=[3529, 1], edge_attr=[162334, 2])
# 33 Data(edge_index=[2, 2111], y=0, label=[1, 4], num_nodes=1058, x=[1058, 1], edge_attr=[2111, 2])
# 34 Data(edge_index=[2, 5525], y=0, label=[1, 4], num_nodes=2774, x=[2774, 1], edge_attr=[5525, 2])
# 35 Data(edge_index=[2, 61171], y=0, label=[1, 4], num_nodes=2940, x=[2940, 1], edge_attr=[61171, 2])
# 36 Data(edge_index=[2, 23761], y=0, label=[1, 4], num_nodes=441, x=[441, 1], edge_attr=[23761, 2])
# 37 Data(edge_index=[2, 68094], y=1, label=[1, 4], num_nodes=4193, x=[4193, 1], edge_attr=[68094, 2])
# 38 Data(edge_index=[2, 91903], y=0, label=[1, 4], num_nodes=691, x=[691, 1], edge_attr=[91903, 2])
# 39 Data(edge_index=[2, 66090], y=0, label=[1, 4], num_nodes=2203, x=[2203, 1], edge_attr=[66090, 2])
# 40 Data(edge_index=[2, 136236], y=0, label=[1, 4], num_nodes=1872, x=[1872, 1], edge_attr=[136236, 2])
# 41 Data(edge_index=[2, 5113], y=1, label=[1, 4], num_nodes=2219, x=[2219, 1], edge_attr=[5113, 2])
# 42 Data(edge_index=[2, 9647], y=0, label=[1, 4], num_nodes=4842, x=[4842, 1], edge_attr=[9647, 2])
# 43 Data(edge_index=[2, 35026], y=0, label=[1, 4], num_nodes=3667, x=[3667, 1], edge_attr=[35026, 2])
# 44 Data(edge_index=[2, 54737], y=0, label=[1, 4], num_nodes=1113, x=[1113, 1], edge_attr=[54737, 2])
# 45 Data(edge_index=[2, 164307], y=0, label=[1, 4], num_nodes=4239, x=[4239, 1], edge_attr=[164307, 2])
# 46 Data(edge_index=[2, 1914], y=0, label=[1, 4], num_nodes=970, x=[970, 1], edge_attr=[1914, 2])
# 47 Data(edge_index=[2, 8652], y=0, label=[1, 4], num_nodes=4333, x=[4333, 1], edge_attr=[8652, 2])
# 48 Data(edge_index=[2, 135785], y=0, label=[1, 4], num_nodes=2616, x=[2616, 1], edge_attr=[135785, 2])
# 49 Data(edge_index=[2, 26033], y=0, label=[1, 4], num_nodes=1137, x=[1137, 1], edge_attr=[26033, 2])
# 50 Data(edge_index=[2, 33552], y=1, label=[1, 4], num_nodes=4522, x=[4522, 1], edge_attr=[33552, 2])
# 51 Data(edge_index=[2, 172728], y=0, label=[1, 4], num_nodes=4798, x=[4798, 1], edge_attr=[172728, 2])
# 52 Data(edge_index=[2, 34029], y=1, label=[1, 4], num_nodes=4576, x=[4576, 1], edge_attr=[34029, 2])
# 53 Data(edge_index=[2, 38139], y=0, label=[1, 4], num_nodes=450, x=[450, 1], edge_attr=[38139, 2])
# 54 Data(edge_index=[2, 17659], y=0, label=[1, 4], num_nodes=4213, x=[4213, 1], edge_attr=[17659, 2])
# 55 Data(edge_index=[2, 8600], y=0, label=[1, 4], num_nodes=4309, x=[4309, 1], edge_attr=[8600, 2])
# 56 Data(edge_index=[2, 7323], y=0, label=[1, 4], num_nodes=3674, x=[3674, 1], edge_attr=[7323, 2])
# 57 Data(edge_index=[2, 4646], y=0, label=[1, 4], num_nodes=2351, x=[2351, 1], edge_attr=[4646, 2])
# 58 Data(edge_index=[2, 91357], y=1, label=[1, 4], num_nodes=3343, x=[3343, 1], edge_attr=[91357, 2])
# 59 Data(edge_index=[2, 160242], y=0, label=[1, 4], num_nodes=4713, x=[4713, 1], edge_attr=[160242, 2])
# 60 Data(edge_index=[2, 33007], y=0, label=[1, 4], num_nodes=2539, x=[2539, 1], edge_attr=[33007, 2])
# 61 Data(edge_index=[2, 4732], y=0, label=[1, 4], num_nodes=193, x=[193, 1], edge_attr=[4732, 2])
# 62 Data(edge_index=[2, 195650], y=0, label=[1, 4], num_nodes=559, x=[559, 1], edge_attr=[195650, 2])
# 63 Data(edge_index=[2, 135894], y=0, label=[1, 4], num_nodes=4118, x=[4118, 1], edge_attr=[135894, 2])
# 64 Data(edge_index=[2, 148487], y=0, label=[1, 4], num_nodes=4152, x=[4152, 1], edge_attr=[148487, 2])
# 65 Data(edge_index=[2, 32547], y=1, label=[1, 4], num_nodes=2889, x=[2889, 1], edge_attr=[32547, 2])
# 66 Data(edge_index=[2, 189362], y=0, label=[1, 4], num_nodes=1297, x=[1297, 1], edge_attr=[189362, 2])
# 67 Data(edge_index=[2, 101343], y=0, label=[1, 4], num_nodes=1543, x=[1543, 1], edge_attr=[101343, 2])
# 68 Data(edge_index=[2, 3959], y=2, label=[1, 4], num_nodes=1982, x=[1982, 1], edge_attr=[3959, 2])
# 69 Data(edge_index=[2, 7337], y=0, label=[1, 4], num_nodes=3702, x=[3702, 1], edge_attr=[7337, 2])
# 70 Data(edge_index=[2, 31256], y=0, label=[1, 4], num_nodes=3907, x=[3907, 1], edge_attr=[31256, 2])
# 71 Data(edge_index=[2, 135523], y=0, label=[1, 4], num_nodes=2297, x=[2297, 1], edge_attr=[135523, 2])
# 72 Data(edge_index=[2, 45710], y=0, label=[1, 4], num_nodes=3265, x=[3265, 1], edge_attr=[45710, 2])
# 73 Data(edge_index=[2, 125293], y=0, label=[1, 4], num_nodes=3951, x=[3951, 1], edge_attr=[125293, 2])
# 74 Data(edge_index=[2, 97929], y=0, label=[1, 4], num_nodes=3627, x=[3627, 1], edge_attr=[97929, 2])
# 75 Data(edge_index=[2, 150535], y=1, label=[1, 4], num_nodes=3438, x=[3438, 1], edge_attr=[150535, 2])
# 76 Data(edge_index=[2, 53970], y=0, label=[1, 4], num_nodes=3855, x=[3855, 1], edge_attr=[53970, 2])
# 77 Data(edge_index=[2, 38997], y=0, label=[1, 4], num_nodes=1857, x=[1857, 1], edge_attr=[38997, 2])
# 78 Data(edge_index=[2, 9410], y=0, label=[1, 4], num_nodes=4714, x=[4714, 1], edge_attr=[9410, 2])
# 79 Data(edge_index=[2, 88777], y=0, label=[1, 4], num_nodes=2682, x=[2682, 1], edge_attr=[88777, 2])
# 80 Data(edge_index=[2, 149554], y=0, label=[1, 4], num_nodes=2276, x=[2276, 1], edge_attr=[149554, 2])
# 81 Data(edge_index=[2, 73548], y=0, label=[1, 4], num_nodes=4044, x=[4044, 1], edge_attr=[73548, 2])
# 82 Data(edge_index=[2, 4780], y=2, label=[1, 4], num_nodes=2402, x=[2402, 1], edge_attr=[4780, 2])
# 83 Data(edge_index=[2, 30275], y=0, label=[1, 4], num_nodes=4325, x=[4325, 1], edge_attr=[30275, 2])
# 84 Data(edge_index=[2, 181842], y=0, label=[1, 4], num_nodes=4664, x=[4664, 1], edge_attr=[181842, 2])
# 85 Data(edge_index=[2, 37490], y=0, label=[1, 4], num_nodes=4944, x=[4944, 1], edge_attr=[37490, 2])
# 86 Data(edge_index=[2, 7936], y=0, label=[1, 4], num_nodes=4022, x=[4022, 1], edge_attr=[7936, 2])
# 87 Data(edge_index=[2, 172550], y=0, label=[1, 4], num_nodes=4930, x=[4930, 1], edge_attr=[172550, 2])
# 88 Data(edge_index=[2, 199049], y=1, label=[1, 4], num_nodes=4449, x=[4449, 1], edge_attr=[199049, 2])
# 89 Data(edge_index=[2, 87714], y=0, label=[1, 4], num_nodes=4873, x=[4873, 1], edge_attr=[87714, 2])
# 90 Data(edge_index=[2, 9608], y=0, label=[1, 4], num_nodes=4866, x=[4866, 1], edge_attr=[9608, 2])
# 91 Data(edge_index=[2, 127925], y=0, label=[1, 4], num_nodes=2787, x=[2787, 1], edge_attr=[127925, 2])
# 92 Data(edge_index=[2, 130861], y=0, label=[1, 4], num_nodes=4881, x=[4881, 1], edge_attr=[130861, 2])
# 93 Data(edge_index=[2, 103152], y=0, label=[1, 4], num_nodes=2115, x=[2115, 1], edge_attr=[103152, 2])
# 94 Data(edge_index=[2, 43707], y=1, label=[1, 4], num_nodes=2470, x=[2470, 1], edge_attr=[43707, 2])
# 95 Data(edge_index=[2, 147909], y=0, label=[1, 4], num_nodes=3147, x=[3147, 1], edge_attr=[147909, 2])
# 96 Data(edge_index=[2, 163003], y=0, label=[1, 4], num_nodes=2121, x=[2121, 1], edge_attr=[163003, 2])
# 97 Data(edge_index=[2, 79355], y=0, label=[1, 4], num_nodes=3311, x=[3311, 1], edge_attr=[79355, 2])
# 98 Data(edge_index=[2, 2723], y=0, label=[1, 4], num_nodes=1396, x=[1396, 1], edge_attr=[2723, 2])
# 99 Data(edge_index=[2, 101591], y=0, label=[1, 4], num_nodes=4417, x=[4417, 1], edge_attr=[101591, 2])
# 100 Data(edge_index=[2, 3675], y=0, label=[1, 4], num_nodes=105, x=[105, 1], edge_attr=[3675, 2])
# 101 Data(edge_index=[2, 71564], y=0, label=[1, 4], num_nodes=3397, x=[3397, 1], edge_attr=[71564, 2])
# 102 Data(edge_index=[2, 135977], y=0, label=[1, 4], num_nodes=1528, x=[1528, 1], edge_attr=[135977, 2])
# 103 Data(edge_index=[2, 105896], y=0, label=[1, 4], num_nodes=1891, x=[1891, 1], edge_attr=[105896, 2])
# 104 Data(edge_index=[2, 103832], y=1, label=[1, 4], num_nodes=3120, x=[3120, 1], edge_attr=[103832, 2])
# 105 Data(edge_index=[2, 126853], y=0, label=[1, 4], num_nodes=2699, x=[2699, 1], edge_attr=[126853, 2])
# 106 Data(edge_index=[2, 6159], y=0, label=[1, 4], num_nodes=3082, x=[3082, 1], edge_attr=[6159, 2])
# 107 Data(edge_index=[2, 140400], y=0, label=[1, 4], num_nodes=1170, x=[1170, 1], edge_attr=[140400, 2])
# 108 Data(edge_index=[2, 101380], y=0, label=[1, 4], num_nodes=1719, x=[1719, 1], edge_attr=[101380, 2])
# 109 Data(edge_index=[2, 102746], y=0, label=[1, 4], num_nodes=3763, x=[3763, 1], edge_attr=[102746, 2])
# 110 Data(edge_index=[2, 9518], y=0, label=[1, 4], num_nodes=4762, x=[4762, 1], edge_attr=[9518, 2])
# 111 Data(edge_index=[2, 177002], y=0, label=[1, 4], num_nodes=2596, x=[2596, 1], edge_attr=[177002, 2])
# 112 Data(edge_index=[2, 150258], y=0, label=[1, 4], num_nodes=951, x=[951, 1], edge_attr=[150258, 2])
# 113 Data(edge_index=[2, 123452], y=0, label=[1, 4], num_nodes=4409, x=[4409, 1], edge_attr=[123452, 2])
# 114 Data(edge_index=[2, 121652], y=0, label=[1, 4], num_nodes=4404, x=[4404, 1], edge_attr=[121652, 2])
# 115 Data(edge_index=[2, 167031], y=0, label=[1, 4], num_nodes=2493, x=[2493, 1], edge_attr=[167031, 2])
# 116 Data(edge_index=[2, 62577], y=0, label=[1, 4], num_nodes=2340, x=[2340, 1], edge_attr=[62577, 2])
# 117 Data(edge_index=[2, 140157], y=0, label=[1, 4], num_nodes=2833, x=[2833, 1], edge_attr=[140157, 2])
# 118 Data(edge_index=[2, 5090], y=0, label=[1, 4], num_nodes=2554, x=[2554, 1], edge_attr=[5090, 2])
# 119 Data(edge_index=[2, 71016], y=0, label=[1, 4], num_nodes=4016, x=[4016, 1], edge_attr=[71016, 2])
# 120 Data(edge_index=[2, 29064], y=0, label=[1, 4], num_nodes=1465, x=[1465, 1], edge_attr=[29064, 2])
# 121 Data(edge_index=[2, 13913], y=0, label=[1, 4], num_nodes=382, x=[382, 1], edge_attr=[13913, 2])
# 122 Data(edge_index=[2, 147559], y=0, label=[1, 4], num_nodes=3599, x=[3599, 1], edge_attr=[147559, 2])
# 123 Data(edge_index=[2, 119310], y=3, label=[1, 4], num_nodes=892, x=[892, 1], edge_attr=[119310, 2])
# 124 Data(edge_index=[2, 44180], y=0, label=[1, 4], num_nodes=2209, x=[2209, 1], edge_attr=[44180, 2])
# 125 Data(edge_index=[2, 156302], y=0, label=[1, 4], num_nodes=2521, x=[2521, 1], edge_attr=[156302, 2])
# 126 Data(edge_index=[2, 184800], y=0, label=[1, 4], num_nodes=4200, x=[4200, 1], edge_attr=[184800, 2])
# 127 Data(edge_index=[2, 173118], y=0, label=[1, 4], num_nodes=2623, x=[2623, 1], edge_attr=[173118, 2])
# 128 Data(edge_index=[2, 35420], y=0, label=[1, 4], num_nodes=1540, x=[1540, 1], edge_attr=[35420, 2])
# 129 Data(edge_index=[2, 83915], y=0, label=[1, 4], num_nodes=1291, x=[1291, 1], edge_attr=[83915, 2])
# 130 Data(edge_index=[2, 125460], y=0, label=[1, 4], num_nodes=3690, x=[3690, 1], edge_attr=[125460, 2])
# 131 Data(edge_index=[2, 41362], y=0, label=[1, 4], num_nodes=1087, x=[1087, 1], edge_attr=[41362, 2])
# 132 Data(edge_index=[2, 110429], y=0, label=[1, 4], num_nodes=1963, x=[1963, 1], edge_attr=[110429, 2])
# 133 Data(edge_index=[2, 29322], y=0, label=[1, 4], num_nodes=181, x=[181, 1], edge_attr=[29322, 2])
# 134 Data(edge_index=[2, 16466], y=0, label=[1, 4], num_nodes=3809, x=[3809, 1], edge_attr=[16466, 2])
# 135 Data(edge_index=[2, 7742], y=0, label=[1, 4], num_nodes=566, x=[566, 1], edge_attr=[7742, 2])
# 136 Data(edge_index=[2, 56172], y=0, label=[1, 4], num_nodes=4681, x=[4681, 1], edge_attr=[56172, 2])
# 137 Data(edge_index=[2, 133136], y=0, label=[1, 4], num_nodes=2512, x=[2512, 1], edge_attr=[133136, 2])
# 138 Data(edge_index=[2, 4688], y=0, label=[1, 4], num_nodes=2358, x=[2358, 1], edge_attr=[4688, 2])
# 139 Data(edge_index=[2, 109350], y=1, label=[1, 4], num_nodes=4114, x=[4114, 1], edge_attr=[109350, 2])
# 140 Data(edge_index=[2, 71134], y=0, label=[1, 4], num_nodes=3616, x=[3616, 1], edge_attr=[71134, 2])
# 141 Data(edge_index=[2, 167352], y=0, label=[1, 4], num_nodes=4404, x=[4404, 1], edge_attr=[167352, 2])
# 142 Data(edge_index=[2, 162292], y=0, label=[1, 4], num_nodes=3121, x=[3121, 1], edge_attr=[162292, 2])
# 143 Data(edge_index=[2, 6587], y=0, label=[1, 4], num_nodes=782, x=[782, 1], edge_attr=[6587, 2])
# 144 Data(edge_index=[2, 144891], y=0, label=[1, 4], num_nodes=4911, x=[4911, 1], edge_attr=[144891, 2])
# 145 Data(edge_index=[2, 4743], y=0, label=[1, 4], num_nodes=2432, x=[2432, 1], edge_attr=[4743, 2])
# 146 Data(edge_index=[2, 165375], y=0, label=[1, 4], num_nodes=2205, x=[2205, 1], edge_attr=[165375, 2])
# 147 Data(edge_index=[2, 174994], y=0, label=[1, 4], num_nodes=2448, x=[2448, 1], edge_attr=[174994, 2])
# 148 Data(edge_index=[2, 197915], y=0, label=[1, 4], num_nodes=4059, x=[4059, 1], edge_attr=[197915, 2])
# 149 Data(edge_index=[2, 61341], y=0, label=[1, 4], num_nodes=2921, x=[2921, 1], edge_attr=[61341, 2])
# 150 Data(edge_index=[2, 5899], y=0, label=[1, 4], num_nodes=3002, x=[3002, 1], edge_attr=[5899, 2])
# 151 Data(edge_index=[2, 135292], y=0, label=[1, 4], num_nodes=1705, x=[1705, 1], edge_attr=[135292, 2])
# 152 Data(edge_index=[2, 196962], y=0, label=[1, 4], num_nodes=3862, x=[3862, 1], edge_attr=[196962, 2])
# 153 Data(edge_index=[2, 199004], y=0, label=[1, 4], num_nodes=4979, x=[4979, 1], edge_attr=[199004, 2])
# 154 Data(edge_index=[2, 99488], y=0, label=[1, 4], num_nodes=4433, x=[4433, 1], edge_attr=[99488, 2])
# 155 Data(edge_index=[2, 92713], y=0, label=[1, 4], num_nodes=4031, x=[4031, 1], edge_attr=[92713, 2])
# 156 Data(edge_index=[2, 140004], y=0, label=[1, 4], num_nodes=3889, x=[3889, 1], edge_attr=[140004, 2])
# 157 Data(edge_index=[2, 103195], y=0, label=[1, 4], num_nodes=4568, x=[4568, 1], edge_attr=[103195, 2])
# 158 Data(edge_index=[2, 115130], y=0, label=[1, 4], num_nodes=3970, x=[3970, 1], edge_attr=[115130, 2])
# 159 Data(edge_index=[2, 38705], y=0, label=[1, 4], num_nodes=357, x=[357, 1], edge_attr=[38705, 2])
# 160 Data(edge_index=[2, 132686], y=0, label=[1, 4], num_nodes=2070, x=[2070, 1], edge_attr=[132686, 2])
# 161 Data(edge_index=[2, 17181], y=0, label=[1, 4], num_nodes=3893, x=[3893, 1], edge_attr=[17181, 2])
# 162 Data(edge_index=[2, 31284], y=0, label=[1, 4], num_nodes=316, x=[316, 1], edge_attr=[31284, 2])
# 163 Data(edge_index=[2, 141310], y=0, label=[1, 4], num_nodes=3572, x=[3572, 1], edge_attr=[141310, 2])
# 164 Data(edge_index=[2, 28025], y=0, label=[1, 4], num_nodes=1121, x=[1121, 1], edge_attr=[28025, 2])
# 165 Data(edge_index=[2, 176064], y=0, label=[1, 4], num_nodes=2751, x=[2751, 1], edge_attr=[176064, 2])
# 166 Data(edge_index=[2, 6436], y=0, label=[1, 4], num_nodes=3257, x=[3257, 1], edge_attr=[6436, 2])
# 167 Data(edge_index=[2, 6638], y=0, label=[1, 4], num_nodes=3362, x=[3362, 1], edge_attr=[6638, 2])
# 168 Data(edge_index=[2, 158132], y=0, label=[1, 4], num_nodes=3041, x=[3041, 1], edge_attr=[158132, 2])
# 169 Data(edge_index=[2, 35975], y=0, label=[1, 4], num_nodes=782, x=[782, 1], edge_attr=[35975, 2])
# 170 Data(edge_index=[2, 20916], y=0, label=[1, 4], num_nodes=1743, x=[1743, 1], edge_attr=[20916, 2])
# 171 Data(edge_index=[2, 180793], y=0, label=[1, 4], num_nodes=1757, x=[1757, 1], edge_attr=[180793, 2])
# 172 Data(edge_index=[2, 116604], y=0, label=[1, 4], num_nodes=474, x=[474, 1], edge_attr=[116604, 2])
# 173 Data(edge_index=[2, 48991], y=1, label=[1, 4], num_nodes=2528, x=[2528, 1], edge_attr=[48991, 2])
# 174 Data(edge_index=[2, 158914], y=1, label=[1, 4], num_nodes=3963, x=[3963, 1], edge_attr=[158914, 2])
# 175 Data(edge_index=[2, 86978], y=0, label=[1, 4], num_nodes=2328, x=[2328, 1], edge_attr=[86978, 2])
# 176 Data(edge_index=[2, 180548], y=0, label=[1, 4], num_nodes=2229, x=[2229, 1], edge_attr=[180548, 2])
# 177 Data(edge_index=[2, 28371], y=0, label=[1, 4], num_nodes=1351, x=[1351, 1], edge_attr=[28371, 2])
# 178 Data(edge_index=[2, 187386], y=1, label=[1, 4], num_nodes=3206, x=[3206, 1], edge_attr=[187386, 2])
# 179 Data(edge_index=[2, 125251], y=0, label=[1, 4], num_nodes=4319, x=[4319, 1], edge_attr=[125251, 2])
# 180 Data(edge_index=[2, 13941], y=0, label=[1, 4], num_nodes=3361, x=[3361, 1], edge_attr=[13941, 2])
# 181 Data(edge_index=[2, 71668], y=0, label=[1, 4], num_nodes=3116, x=[3116, 1], edge_attr=[71668, 2])
# 182 Data(edge_index=[2, 44792], y=0, label=[1, 4], num_nodes=2036, x=[2036, 1], edge_attr=[44792, 2])
# 183 Data(edge_index=[2, 19073], y=1, label=[1, 4], num_nodes=1233, x=[1233, 1], edge_attr=[19073, 2])
# 184 Data(edge_index=[2, 134442], y=0, label=[1, 4], num_nodes=3201, x=[3201, 1], edge_attr=[134442, 2])
# 185 Data(edge_index=[2, 49745], y=0, label=[1, 4], num_nodes=1875, x=[1875, 1], edge_attr=[49745, 2])
# 186 Data(edge_index=[2, 115312], y=0, label=[1, 4], num_nodes=829, x=[829, 1], edge_attr=[115312, 2])
# 187 Data(edge_index=[2, 62680], y=0, label=[1, 4], num_nodes=2391, x=[2391, 1], edge_attr=[62680, 2])
# 188 Data(edge_index=[2, 6639], y=0, label=[1, 4], num_nodes=466, x=[466, 1], edge_attr=[6639, 2])
# 189 Data(edge_index=[2, 107909], y=0, label=[1, 4], num_nodes=1548, x=[1548, 1], edge_attr=[107909, 2])
# 190 Data(edge_index=[2, 10682], y=0, label=[1, 4], num_nodes=109, x=[109, 1], edge_attr=[10682, 2])
# 191 Data(edge_index=[2, 9846], y=0, label=[1, 4], num_nodes=4951, x=[4951, 1], edge_attr=[9846, 2])
# 192 Data(edge_index=[2, 33034], y=0, label=[1, 4], num_nodes=1617, x=[1617, 1], edge_attr=[33034, 2])
# 193 Data(edge_index=[2, 5826], y=0, label=[1, 4], num_nodes=2947, x=[2947, 1], edge_attr=[5826, 2])
# 194 Data(edge_index=[2, 180547], y=0, label=[1, 4], num_nodes=4416, x=[4416, 1], edge_attr=[180547, 2])
# 195 Data(edge_index=[2, 62289], y=0, label=[1, 4], num_nodes=4365, x=[4365, 1], edge_attr=[62289, 2])
# 196 Data(edge_index=[2, 6497], y=0, label=[1, 4], num_nodes=3278, x=[3278, 1], edge_attr=[6497, 2])
# 197 Data(edge_index=[2, 105478], y=0, label=[1, 4], num_nodes=4835, x=[4835, 1], edge_attr=[105478, 2])
# 198 Data(edge_index=[2, 151197], y=1, label=[1, 4], num_nodes=4989, x=[4989, 1], edge_attr=[151197, 2])
# 199 Data(edge_index=[2, 8706], y=0, label=[1, 4], num_nodes=205, x=[205, 1], edge_attr=[8706, 2])
# 200 Data(edge_index=[2, 75929], y=0, label=[1, 4], num_nodes=4813, x=[4813, 1], edge_attr=[75929, 2])
# 201 Data(edge_index=[2, 127044], y=0, label=[1, 4], num_nodes=3440, x=[3440, 1], edge_attr=[127044, 2])
# 202 Data(edge_index=[2, 21685], y=0, label=[1, 4], num_nodes=2629, x=[2629, 1], edge_attr=[21685, 2])
# 203 Data(edge_index=[2, 6738], y=0, label=[1, 4], num_nodes=3427, x=[3427, 1], edge_attr=[6738, 2])
# 204 Data(edge_index=[2, 57249], y=0, label=[1, 4], num_nodes=4941, x=[4941, 1], edge_attr=[57249, 2])
# 205 Data(edge_index=[2, 154745], y=0, label=[1, 4], num_nodes=4873, x=[4873, 1], edge_attr=[154745, 2])
# 206 Data(edge_index=[2, 6359], y=3, label=[1, 4], num_nodes=3200, x=[3200, 1], edge_attr=[6359, 2])
# 207 Data(edge_index=[2, 66918], y=0, label=[1, 4], num_nodes=1761, x=[1761, 1], edge_attr=[66918, 2])
# 208 Data(edge_index=[2, 192419], y=1, label=[1, 4], num_nodes=3975, x=[3975, 1], edge_attr=[192419, 2])
# 209 Data(edge_index=[2, 101650], y=0, label=[1, 4], num_nodes=2033, x=[2033, 1], edge_attr=[101650, 2])
# 210 Data(edge_index=[2, 86560], y=0, label=[1, 4], num_nodes=3953, x=[3953, 1], edge_attr=[86560, 2])
# 211 Data(edge_index=[2, 84530], y=0, label=[1, 4], num_nodes=2523, x=[2523, 1], edge_attr=[84530, 2])
# 212 Data(edge_index=[2, 36606], y=0, label=[1, 4], num_nodes=746, x=[746, 1], edge_attr=[36606, 2])
# 213 Data(edge_index=[2, 27578], y=1, label=[1, 4], num_nodes=2195, x=[2195, 1], edge_attr=[27578, 2])
# 214 Data(edge_index=[2, 185276], y=0, label=[1, 4], num_nodes=3563, x=[3563, 1], edge_attr=[185276, 2])
# 215 Data(edge_index=[2, 4659], y=0, label=[1, 4], num_nodes=2342, x=[2342, 1], edge_attr=[4659, 2])
# 216 Data(edge_index=[2, 166500], y=0, label=[1, 4], num_nodes=4625, x=[4625, 1], edge_attr=[166500, 2])
# 217 Data(edge_index=[2, 129417], y=1, label=[1, 4], num_nodes=3942, x=[3942, 1], edge_attr=[129417, 2])
# 218 Data(edge_index=[2, 13834], y=0, label=[1, 4], num_nodes=614, x=[614, 1], edge_attr=[13834, 2])
# 219 Data(edge_index=[2, 32487], y=1, label=[1, 4], num_nodes=3727, x=[3727, 1], edge_attr=[32487, 2])
# 220 Data(edge_index=[2, 29135], y=0, label=[1, 4], num_nodes=2948, x=[2948, 1], edge_attr=[29135, 2])
# 221 Data(edge_index=[2, 82833], y=1, label=[1, 4], num_nodes=4489, x=[4489, 1], edge_attr=[82833, 2])
# 222 Data(edge_index=[2, 9518], y=0, label=[1, 4], num_nodes=4762, x=[4762, 1], edge_attr=[9518, 2])
# 223 Data(edge_index=[2, 18665], y=0, label=[1, 4], num_nodes=4453, x=[4453, 1], edge_attr=[18665, 2])
# 224 Data(edge_index=[2, 142592], y=0, label=[1, 4], num_nodes=4456, x=[4456, 1], edge_attr=[142592, 2])
# 225 Data(edge_index=[2, 187128], y=1, label=[1, 4], num_nodes=1651, x=[1651, 1], edge_attr=[187128, 2])
# 226 Data(edge_index=[2, 66422], y=1, label=[1, 4], num_nodes=1390, x=[1390, 1], edge_attr=[66422, 2])
# 227 Data(edge_index=[2, 163836], y=0, label=[1, 4], num_nodes=4551, x=[4551, 1], edge_attr=[163836, 2])
# 228 Data(edge_index=[2, 100352], y=0, label=[1, 4], num_nodes=1736, x=[1736, 1], edge_attr=[100352, 2])
# 229 Data(edge_index=[2, 85140], y=1, label=[1, 4], num_nodes=2954, x=[2954, 1], edge_attr=[85140, 2])
# 230 Data(edge_index=[2, 74308], y=0, label=[1, 4], num_nodes=1429, x=[1429, 1], edge_attr=[74308, 2])
# 231 Data(edge_index=[2, 106784], y=0, label=[1, 4], num_nodes=3337, x=[3337, 1], edge_attr=[106784, 2])
# 232 Data(edge_index=[2, 102116], y=1, label=[1, 4], num_nodes=1777, x=[1777, 1], edge_attr=[102116, 2])
# 233 Data(edge_index=[2, 1699], y=0, label=[1, 4], num_nodes=860, x=[860, 1], edge_attr=[1699, 2])
# 234 Data(edge_index=[2, 30195], y=0, label=[1, 4], num_nodes=1163, x=[1163, 1], edge_attr=[30195, 2])
# 235 Data(edge_index=[2, 8453], y=0, label=[1, 4], num_nodes=4302, x=[4302, 1], edge_attr=[8453, 2])
# 236 Data(edge_index=[2, 9497], y=0, label=[1, 4], num_nodes=4862, x=[4862, 1], edge_attr=[9497, 2])
# 237 Data(edge_index=[2, 93214], y=0, label=[1, 4], num_nodes=3324, x=[3324, 1], edge_attr=[93214, 2])
# 238 Data(edge_index=[2, 179052], y=0, label=[1, 4], num_nodes=694, x=[694, 1], edge_attr=[179052, 2])
# 239 Data(edge_index=[2, 6098], y=0, label=[1, 4], num_nodes=3107, x=[3107, 1], edge_attr=[6098, 2])
# 240 Data(edge_index=[2, 3938], y=0, label=[1, 4], num_nodes=871, x=[871, 1], edge_attr=[3938, 2])
# 241 Data(edge_index=[2, 22660], y=0, label=[1, 4], num_nodes=669, x=[669, 1], edge_attr=[22660, 2])
# 242 Data(edge_index=[2, 5077], y=0, label=[1, 4], num_nodes=2558, x=[2558, 1], edge_attr=[5077, 2])
# 243 Data(edge_index=[2, 9364], y=3, label=[1, 4], num_nodes=4745, x=[4745, 1], edge_attr=[9364, 2])
# 244 Data(edge_index=[2, 3196], y=0, label=[1, 4], num_nodes=1601, x=[1601, 1], edge_attr=[3196, 2])
# 245 Data(edge_index=[2, 84245], y=0, label=[1, 4], num_nodes=2905, x=[2905, 1], edge_attr=[84245, 2])
# 246 Data(edge_index=[2, 154739], y=0, label=[1, 4], num_nodes=3093, x=[3093, 1], edge_attr=[154739, 2])
# 247 Data(edge_index=[2, 24689], y=0, label=[1, 4], num_nodes=1107, x=[1107, 1], edge_attr=[24689, 2])
# 248 Data(edge_index=[2, 15586], y=0, label=[1, 4], num_nodes=1181, x=[1181, 1], edge_attr=[15586, 2])
# 249 Data(edge_index=[2, 91605], y=0, label=[1, 4], num_nodes=4388, x=[4388, 1], edge_attr=[91605, 2])
# 250 Data(edge_index=[2, 14344], y=0, label=[1, 4], num_nodes=1793, x=[1793, 1], edge_attr=[14344, 2])
# 251 Data(edge_index=[2, 4013], y=0, label=[1, 4], num_nodes=2016, x=[2016, 1], edge_attr=[4013, 2])
# 252 Data(edge_index=[2, 6898], y=0, label=[1, 4], num_nodes=3467, x=[3467, 1], edge_attr=[6898, 2])
# 253 Data(edge_index=[2, 136345], y=0, label=[1, 4], num_nodes=3685, x=[3685, 1], edge_attr=[136345, 2])
# 254 Data(edge_index=[2, 172525], y=0, label=[1, 4], num_nodes=2575, x=[2575, 1], edge_attr=[172525, 2])
# 255 Data(edge_index=[2, 83540], y=0, label=[1, 4], num_nodes=4177, x=[4177, 1], edge_attr=[83540, 2])
# 256 Data(edge_index=[2, 106064], y=0, label=[1, 4], num_nodes=3846, x=[3846, 1], edge_attr=[106064, 2])
# 257 Data(edge_index=[2, 125445], y=1, label=[1, 4], num_nodes=3631, x=[3631, 1], edge_attr=[125445, 2])
# 258 Data(edge_index=[2, 88322], y=0, label=[1, 4], num_nodes=3397, x=[3397, 1], edge_attr=[88322, 2])
# 259 Data(edge_index=[2, 115304], y=0, label=[1, 4], num_nodes=3976, x=[3976, 1], edge_attr=[115304, 2])
# 260 Data(edge_index=[2, 48558], y=0, label=[1, 4], num_nodes=2558, x=[2558, 1], edge_attr=[48558, 2])
# 261 Data(edge_index=[2, 140612], y=1, label=[1, 4], num_nodes=4840, x=[4840, 1], edge_attr=[140612, 2])
# 262 Data(edge_index=[2, 160914], y=0, label=[1, 4], num_nodes=4126, x=[4126, 1], edge_attr=[160914, 2])
# 263 Data(edge_index=[2, 33761], y=0, label=[1, 4], num_nodes=2597, x=[2597, 1], edge_attr=[33761, 2])
# 264 Data(edge_index=[2, 35728], y=0, label=[1, 4], num_nodes=1276, x=[1276, 1], edge_attr=[35728, 2])
# 265 Data(edge_index=[2, 5255], y=0, label=[1, 4], num_nodes=2634, x=[2634, 1], edge_attr=[5255, 2])
# 266 Data(edge_index=[2, 1229], y=0, label=[1, 4], num_nodes=640, x=[640, 1], edge_attr=[1229, 2])
# 267 Data(edge_index=[2, 41552], y=0, label=[1, 4], num_nodes=2968, x=[2968, 1], edge_attr=[41552, 2])
# 268 Data(edge_index=[2, 22617], y=0, label=[1, 4], num_nodes=3231, x=[3231, 1], edge_attr=[22617, 2])
# 269 Data(edge_index=[2, 181125], y=0, label=[1, 4], num_nodes=2625, x=[2625, 1], edge_attr=[181125, 2])
# 270 Data(edge_index=[2, 175320], y=0, label=[1, 4], num_nodes=3896, x=[3896, 1], edge_attr=[175320, 2])
# 271 Data(edge_index=[2, 118245], y=0, label=[1, 4], num_nodes=2769, x=[2769, 1], edge_attr=[118245, 2])
# 272 Data(edge_index=[2, 34287], y=0, label=[1, 4], num_nodes=2226, x=[2226, 1], edge_attr=[34287, 2])
# 273 Data(edge_index=[2, 7702], y=0, label=[1, 4], num_nodes=3887, x=[3887, 1], edge_attr=[7702, 2])
# 274 Data(edge_index=[2, 37388], y=0, label=[1, 4], num_nodes=1807, x=[1807, 1], edge_attr=[37388, 2])
# 275 Data(edge_index=[2, 4345], y=0, label=[1, 4], num_nodes=276, x=[276, 1], edge_attr=[4345, 2])
# 276 Data(edge_index=[2, 114183], y=0, label=[1, 4], num_nodes=4229, x=[4229, 1], edge_attr=[114183, 2])
# 277 Data(edge_index=[2, 9816], y=0, label=[1, 4], num_nodes=4966, x=[4966, 1], edge_attr=[9816, 2])
# 278 Data(edge_index=[2, 155804], y=0, label=[1, 4], num_nodes=3541, x=[3541, 1], edge_attr=[155804, 2])
# 279 Data(edge_index=[2, 164956], y=0, label=[1, 4], num_nodes=1793, x=[1793, 1], edge_attr=[164956, 2])
# 280 Data(edge_index=[2, 123584], y=0, label=[1, 4], num_nodes=4165, x=[4165, 1], edge_attr=[123584, 2])
# 281 Data(edge_index=[2, 2513], y=0, label=[1, 4], num_nodes=1260, x=[1260, 1], edge_attr=[2513, 2])
# 282 Data(edge_index=[2, 52330], y=0, label=[1, 4], num_nodes=2472, x=[2472, 1], edge_attr=[52330, 2])
# 283 Data(edge_index=[2, 174041], y=0, label=[1, 4], num_nodes=1081, x=[1081, 1], edge_attr=[174041, 2])
# 284 Data(edge_index=[2, 2622], y=0, label=[1, 4], num_nodes=172, x=[172, 1], edge_attr=[2622, 2])
# 285 Data(edge_index=[2, 74277], y=0, label=[1, 4], num_nodes=1179, x=[1179, 1], edge_attr=[74277, 2])
# 286 Data(edge_index=[2, 63528], y=1, label=[1, 4], num_nodes=3026, x=[3026, 1], edge_attr=[63528, 2])
# 287 Data(edge_index=[2, 45000], y=0, label=[1, 4], num_nodes=375, x=[375, 1], edge_attr=[45000, 2])
# 288 Data(edge_index=[2, 19459], y=1, label=[1, 4], num_nodes=2717, x=[2717, 1], edge_attr=[19459, 2])
# 289 Data(edge_index=[2, 4667], y=0, label=[1, 4], num_nodes=2358, x=[2358, 1], edge_attr=[4667, 2])
# 290 Data(edge_index=[2, 119882], y=0, label=[1, 4], num_nodes=3389, x=[3389, 1], edge_attr=[119882, 2])
# 291 Data(edge_index=[2, 85472], y=0, label=[1, 4], num_nodes=2671, x=[2671, 1], edge_attr=[85472, 2])
# 292 Data(edge_index=[2, 53240], y=0, label=[1, 4], num_nodes=2420, x=[2420, 1], edge_attr=[53240, 2])
# 293 Data(edge_index=[2, 66791], y=0, label=[1, 4], num_nodes=3497, x=[3497, 1], edge_attr=[66791, 2])
# 294 Data(edge_index=[2, 7456], y=3, label=[1, 4], num_nodes=3842, x=[3842, 1], edge_attr=[7456, 2])
# 295 Data(edge_index=[2, 52066], y=0, label=[1, 4], num_nodes=929, x=[929, 1], edge_attr=[52066, 2])
# 296 Data(edge_index=[2, 30161], y=0, label=[1, 4], num_nodes=2709, x=[2709, 1], edge_attr=[30161, 2])
# 297 Data(edge_index=[2, 4978], y=0, label=[1, 4], num_nodes=2522, x=[2522, 1], edge_attr=[4978, 2])
# 298 Data(edge_index=[2, 134829], y=1, label=[1, 4], num_nodes=4997, x=[4997, 1], edge_attr=[134829, 2])
# 299 Data(edge_index=[2, 59982], y=0, label=[1, 4], num_nodes=769, x=[769, 1], edge_attr=[59982, 2])
# 300 Data(edge_index=[2, 101589], y=0, label=[1, 4], num_nodes=1135, x=[1135, 1], edge_attr=[101589, 2])
# 301 Data(edge_index=[2, 71593], y=1, label=[1, 4], num_nodes=2835, x=[2835, 1], edge_attr=[71593, 2])
# 302 Data(edge_index=[2, 16790], y=0, label=[1, 4], num_nodes=1956, x=[1956, 1], edge_attr=[16790, 2])
# 303 Data(edge_index=[2, 71627], y=0, label=[1, 4], num_nodes=1422, x=[1422, 1], edge_attr=[71627, 2])
# 304 Data(edge_index=[2, 118828], y=0, label=[1, 4], num_nodes=974, x=[974, 1], edge_attr=[118828, 2])
# 305 Data(edge_index=[2, 115031], y=0, label=[1, 4], num_nodes=1256, x=[1256, 1], edge_attr=[115031, 2])
# 306 Data(edge_index=[2, 116380], y=0, label=[1, 4], num_nodes=529, x=[529, 1], edge_attr=[116380, 2])
# 307 Data(edge_index=[2, 40362], y=0, label=[1, 4], num_nodes=2883, x=[2883, 1], edge_attr=[40362, 2])
# 308 Data(edge_index=[2, 119239], y=0, label=[1, 4], num_nodes=1193, x=[1193, 1], edge_attr=[119239, 2])
# 309 Data(edge_index=[2, 61131], y=0, label=[1, 4], num_nodes=2911, x=[2911, 1], edge_attr=[61131, 2])
# 310 Data(edge_index=[2, 30560], y=0, label=[1, 4], num_nodes=3820, x=[3820, 1], edge_attr=[30560, 2])
# 311 Data(edge_index=[2, 105931], y=0, label=[1, 4], num_nodes=3083, x=[3083, 1], edge_attr=[105931, 2])
# 312 Data(edge_index=[2, 3488], y=0, label=[1, 4], num_nodes=1750, x=[1750, 1], edge_attr=[3488, 2])
# 313 Data(edge_index=[2, 9223], y=0, label=[1, 4], num_nodes=4646, x=[4646, 1], edge_attr=[9223, 2])
# 314 Data(edge_index=[2, 86125], y=0, label=[1, 4], num_nodes=1625, x=[1625, 1], edge_attr=[86125, 2])
# 315 Data(edge_index=[2, 66990], y=0, label=[1, 4], num_nodes=4785, x=[4785, 1], edge_attr=[66990, 2])
# 316 Data(edge_index=[2, 873], y=0, label=[1, 4], num_nodes=113, x=[113, 1], edge_attr=[873, 2])
# 317 Data(edge_index=[2, 13114], y=0, label=[1, 4], num_nodes=2971, x=[2971, 1], edge_attr=[13114, 2])
# 318 Data(edge_index=[2, 60633], y=0, label=[1, 4], num_nodes=1026, x=[1026, 1], edge_attr=[60633, 2])
# 319 Data(edge_index=[2, 29331], y=0, label=[1, 4], num_nodes=4641, x=[4641, 1], edge_attr=[29331, 2])
# 320 Data(edge_index=[2, 32574], y=0, label=[1, 4], num_nodes=880, x=[880, 1], edge_attr=[32574, 2])
# 321 Data(edge_index=[2, 99896], y=0, label=[1, 4], num_nodes=2659, x=[2659, 1], edge_attr=[99896, 2])
# 322 Data(edge_index=[2, 99209], y=0, label=[1, 4], num_nodes=3421, x=[3421, 1], edge_attr=[99209, 2])
# 323 Data(edge_index=[2, 134130], y=0, label=[1, 4], num_nodes=3945, x=[3945, 1], edge_attr=[134130, 2])
# 324 Data(edge_index=[2, 113586], y=0, label=[1, 4], num_nodes=1721, x=[1721, 1], edge_attr=[113586, 2])
# 325 Data(edge_index=[2, 89070], y=0, label=[1, 4], num_nodes=1570, x=[1570, 1], edge_attr=[89070, 2])
# 326 Data(edge_index=[2, 9070], y=0, label=[1, 4], num_nodes=4559, x=[4559, 1], edge_attr=[9070, 2])
# 327 Data(edge_index=[2, 65415], y=0, label=[1, 4], num_nodes=4361, x=[4361, 1], edge_attr=[65415, 2])
# 328 Data(edge_index=[2, 12554], y=0, label=[1, 4], num_nodes=373, x=[373, 1], edge_attr=[12554, 2])
# 329 Data(edge_index=[2, 39631], y=0, label=[1, 4], num_nodes=2918, x=[2918, 1], edge_attr=[39631, 2])
# 330 Data(edge_index=[2, 191014], y=0, label=[1, 4], num_nodes=3207, x=[3207, 1], edge_attr=[191014, 2])
# 331 Data(edge_index=[2, 8384], y=0, label=[1, 4], num_nodes=4237, x=[4237, 1], edge_attr=[8384, 2])
# 332 Data(edge_index=[2, 194122], y=0, label=[1, 4], num_nodes=961, x=[961, 1], edge_attr=[194122, 2])
# 333 Data(edge_index=[2, 141710], y=0, label=[1, 4], num_nodes=766, x=[766, 1], edge_attr=[141710, 2])
# 334 Data(edge_index=[2, 46300], y=0, label=[1, 4], num_nodes=688, x=[688, 1], edge_attr=[46300, 2])
# 335 Data(edge_index=[2, 6272], y=0, label=[1, 4], num_nodes=3138, x=[3138, 1], edge_attr=[6272, 2])
# 336 Data(edge_index=[2, 6063], y=0, label=[1, 4], num_nodes=3040, x=[3040, 1], edge_attr=[6063, 2])
# 337 Data(edge_index=[2, 2633], y=0, label=[1, 4], num_nodes=1336, x=[1336, 1], edge_attr=[2633, 2])
# 338 Data(edge_index=[2, 81693], y=0, label=[1, 4], num_nodes=3053, x=[3053, 1], edge_attr=[81693, 2])
# 339 Data(edge_index=[2, 158735], y=0, label=[1, 4], num_nodes=564, x=[564, 1], edge_attr=[158735, 2])
# 340 Data(edge_index=[2, 165163], y=0, label=[1, 4], num_nodes=3841, x=[3841, 1], edge_attr=[165163, 2])
# 341 Data(edge_index=[2, 78207], y=0, label=[1, 4], num_nodes=393, x=[393, 1], edge_attr=[78207, 2])
# 342 Data(edge_index=[2, 172482], y=0, label=[1, 4], num_nodes=3382, x=[3382, 1], edge_attr=[172482, 2])
# 343 Data(edge_index=[2, 128949], y=0, label=[1, 4], num_nodes=2433, x=[2433, 1], edge_attr=[128949, 2])
# 344 Data(edge_index=[2, 139872], y=0, label=[1, 4], num_nodes=4371, x=[4371, 1], edge_attr=[139872, 2])
# 345 Data(edge_index=[2, 173108], y=0, label=[1, 4], num_nodes=3329, x=[3329, 1], edge_attr=[173108, 2])
# 346 Data(edge_index=[2, 18800], y=0, label=[1, 4], num_nodes=648, x=[648, 1], edge_attr=[18800, 2])
# 347 Data(edge_index=[2, 12922], y=0, label=[1, 4], num_nodes=1846, x=[1846, 1], edge_attr=[12922, 2])
# 348 Data(edge_index=[2, 64098], y=0, label=[1, 4], num_nodes=3561, x=[3561, 1], edge_attr=[64098, 2])
# 349 Data(edge_index=[2, 149232], y=0, label=[1, 4], num_nodes=3109, x=[3109, 1], edge_attr=[149232, 2])
# 350 Data(edge_index=[2, 85335], y=0, label=[1, 4], num_nodes=854, x=[854, 1], edge_attr=[85335, 2])
# 351 Data(edge_index=[2, 3161], y=0, label=[1, 4], num_nodes=1602, x=[1602, 1], edge_attr=[3161, 2])
# 352 Data(edge_index=[2, 43552], y=1, label=[1, 4], num_nodes=2210, x=[2210, 1], edge_attr=[43552, 2])
# 353 Data(edge_index=[2, 39150], y=0, label=[1, 4], num_nodes=1739, x=[1739, 1], edge_attr=[39150, 2])
# 354 Data(edge_index=[2, 176919], y=0, label=[1, 4], num_nodes=3469, x=[3469, 1], edge_attr=[176919, 2])
# 355 Data(edge_index=[2, 139993], y=0, label=[1, 4], num_nodes=2857, x=[2857, 1], edge_attr=[139993, 2])
# 356 Data(edge_index=[2, 162801], y=0, label=[1, 4], num_nodes=4500, x=[4500, 1], edge_attr=[162801, 2])
# 357 Data(edge_index=[2, 3553], y=0, label=[1, 4], num_nodes=1820, x=[1820, 1], edge_attr=[3553, 2])
# 358 Data(edge_index=[2, 29306], y=0, label=[1, 4], num_nodes=585, x=[585, 1], edge_attr=[29306, 2])
# 359 Data(edge_index=[2, 121500], y=0, label=[1, 4], num_nodes=375, x=[375, 1], edge_attr=[121500, 2])
# 360 Data(edge_index=[2, 14912], y=0, label=[1, 4], num_nodes=3268, x=[3268, 1], edge_attr=[14912, 2])
# 361 Data(edge_index=[2, 172932], y=0, label=[1, 4], num_nodes=4353, x=[4353, 1], edge_attr=[172932, 2])
# 362 Data(edge_index=[2, 147456], y=0, label=[1, 4], num_nodes=2304, x=[2304, 1], edge_attr=[147456, 2])
# 363 Data(edge_index=[2, 73485], y=0, label=[1, 4], num_nodes=4899, x=[4899, 1], edge_attr=[73485, 2])
# 364 Data(edge_index=[2, 129895], y=0, label=[1, 4], num_nodes=4492, x=[4492, 1], edge_attr=[129895, 2])
# 365 Data(edge_index=[2, 11379], y=0, label=[1, 4], num_nodes=499, x=[499, 1], edge_attr=[11379, 2])
# 366 Data(edge_index=[2, 131236], y=0, label=[1, 4], num_nodes=4687, x=[4687, 1], edge_attr=[131236, 2])
# 367 Data(edge_index=[2, 5077], y=0, label=[1, 4], num_nodes=173, x=[173, 1], edge_attr=[5077, 2])
# 368 Data(edge_index=[2, 111100], y=0, label=[1, 4], num_nodes=3857, x=[3857, 1], edge_attr=[111100, 2])
# 369 Data(edge_index=[2, 118880], y=0, label=[1, 4], num_nodes=1486, x=[1486, 1], edge_attr=[118880, 2])
# 370 Data(edge_index=[2, 102047], y=0, label=[1, 4], num_nodes=2676, x=[2676, 1], edge_attr=[102047, 2])
# 371 Data(edge_index=[2, 12469], y=0, label=[1, 4], num_nodes=2773, x=[2773, 1], edge_attr=[12469, 2])
# 372 Data(edge_index=[2, 193581], y=0, label=[1, 4], num_nodes=2668, x=[2668, 1], edge_attr=[193581, 2])
# 373 Data(edge_index=[2, 8935], y=0, label=[1, 4], num_nodes=4484, x=[4484, 1], edge_attr=[8935, 2])
# 374 Data(edge_index=[2, 2261], y=0, label=[1, 4], num_nodes=215, x=[215, 1], edge_attr=[2261, 2])
# 375 Data(edge_index=[2, 165293], y=0, label=[1, 4], num_nodes=2651, x=[2651, 1], edge_attr=[165293, 2])
# 376 Data(edge_index=[2, 135399], y=0, label=[1, 4], num_nodes=1119, x=[1119, 1], edge_attr=[135399, 2])
# 377 Data(edge_index=[2, 76296], y=0, label=[1, 4], num_nodes=1156, x=[1156, 1], edge_attr=[76296, 2])
# 378 Data(edge_index=[2, 72073], y=0, label=[1, 4], num_nodes=1296, x=[1296, 1], edge_attr=[72073, 2])
# 379 Data(edge_index=[2, 122669], y=0, label=[1, 4], num_nodes=589, x=[589, 1], edge_attr=[122669, 2])
# 380 Data(edge_index=[2, 62220], y=0, label=[1, 4], num_nodes=772, x=[772, 1], edge_attr=[62220, 2])
# 381 Data(edge_index=[2, 12529], y=0, label=[1, 4], num_nodes=2885, x=[2885, 1], edge_attr=[12529, 2])
# 382 Data(edge_index=[2, 1613], y=0, label=[1, 4], num_nodes=816, x=[816, 1], edge_attr=[1613, 2])
# 383 Data(edge_index=[2, 1062], y=0, label=[1, 4], num_nodes=147, x=[147, 1], edge_attr=[1062, 2])
# 384 Data(edge_index=[2, 194373], y=1, label=[1, 4], num_nodes=4476, x=[4476, 1], edge_attr=[194373, 2])
# 385 Data(edge_index=[2, 64545], y=0, label=[1, 4], num_nodes=1048, x=[1048, 1], edge_attr=[64545, 2])
# 386 Data(edge_index=[2, 7091], y=0, label=[1, 4], num_nodes=3566, x=[3566, 1], edge_attr=[7091, 2])
# 387 Data(edge_index=[2, 166272], y=0, label=[1, 4], num_nodes=2598, x=[2598, 1], edge_attr=[166272, 2])
# 388 Data(edge_index=[2, 108029], y=1, label=[1, 4], num_nodes=1871, x=[1871, 1], edge_attr=[108029, 2])
# 389 Data(edge_index=[2, 77232], y=0, label=[1, 4], num_nodes=3053, x=[3053, 1], edge_attr=[77232, 2])
# 390 Data(edge_index=[2, 86776], y=1, label=[1, 4], num_nodes=3562, x=[3562, 1], edge_attr=[86776, 2])
# 391 Data(edge_index=[2, 9824], y=2, label=[1, 4], num_nodes=4930, x=[4930, 1], edge_attr=[9824, 2])
# 392 Data(edge_index=[2, 93063], y=0, label=[1, 4], num_nodes=362, x=[362, 1], edge_attr=[93063, 2])
# 393 Data(edge_index=[2, 6871], y=0, label=[1, 4], num_nodes=3452, x=[3452, 1], edge_attr=[6871, 2])
# 394 Data(edge_index=[2, 134127], y=0, label=[1, 4], num_nodes=3896, x=[3896, 1], edge_attr=[134127, 2])
# 395 Data(edge_index=[2, 37771], y=0, label=[1, 4], num_nodes=353, x=[353, 1], edge_attr=[37771, 2])
# 396 Data(edge_index=[2, 2915], y=0, label=[1, 4], num_nodes=1502, x=[1502, 1], edge_attr=[2915, 2])
# 397 Data(edge_index=[2, 25416], y=0, label=[1, 4], num_nodes=2461, x=[2461, 1], edge_attr=[25416, 2])
# 398 Data(edge_index=[2, 39492], y=0, label=[1, 4], num_nodes=2194, x=[2194, 1], edge_attr=[39492, 2])
# 399 Data(edge_index=[2, 119132], y=0, label=[1, 4], num_nodes=388, x=[388, 1], edge_attr=[119132, 2])
# 400 Data(edge_index=[2, 3398], y=0, label=[1, 4], num_nodes=1727, x=[1727, 1], edge_attr=[3398, 2])
# 401 Data(edge_index=[2, 111422], y=0, label=[1, 4], num_nodes=1081, x=[1081, 1], edge_attr=[111422, 2])
# 402 Data(edge_index=[2, 4449], y=0, label=[1, 4], num_nodes=305, x=[305, 1], edge_attr=[4449, 2])
# 403 Data(edge_index=[2, 81490], y=0, label=[1, 4], num_nodes=562, x=[562, 1], edge_attr=[81490, 2])
# 404 Data(edge_index=[2, 19528], y=0, label=[1, 4], num_nodes=434, x=[434, 1], edge_attr=[19528, 2])
# 405 Data(edge_index=[2, 77207], y=0, label=[1, 4], num_nodes=3594, x=[3594, 1], edge_attr=[77207, 2])
# 406 Data(edge_index=[2, 8408], y=0, label=[1, 4], num_nodes=1886, x=[1886, 1], edge_attr=[8408, 2])
# 407 Data(edge_index=[2, 116136], y=1, label=[1, 4], num_nodes=4418, x=[4418, 1], edge_attr=[116136, 2])
# 408 Data(edge_index=[2, 57869], y=0, label=[1, 4], num_nodes=1288, x=[1288, 1], edge_attr=[57869, 2])
# 409 Data(edge_index=[2, 71460], y=0, label=[1, 4], num_nodes=4764, x=[4764, 1], edge_attr=[71460, 2])
# 410 Data(edge_index=[2, 42307], y=0, label=[1, 4], num_nodes=2875, x=[2875, 1], edge_attr=[42307, 2])
# 411 Data(edge_index=[2, 25062], y=0, label=[1, 4], num_nodes=3823, x=[3823, 1], edge_attr=[25062, 2])
# 412 Data(edge_index=[2, 40587], y=1, label=[1, 4], num_nodes=1694, x=[1694, 1], edge_attr=[40587, 2])
# 413 Data(edge_index=[2, 30311], y=0, label=[1, 4], num_nodes=1783, x=[1783, 1], edge_attr=[30311, 2])
# 414 Data(edge_index=[2, 74935], y=0, label=[1, 4], num_nodes=2141, x=[2141, 1], edge_attr=[74935, 2])
# 415 Data(edge_index=[2, 59641], y=1, label=[1, 4], num_nodes=1466, x=[1466, 1], edge_attr=[59641, 2])
# 416 Data(edge_index=[2, 180601], y=1, label=[1, 4], num_nodes=1869, x=[1869, 1], edge_attr=[180601, 2])
# 417 Data(edge_index=[2, 35827], y=0, label=[1, 4], num_nodes=4139, x=[4139, 1], edge_attr=[35827, 2])
# 418 Data(edge_index=[2, 5141], y=0, label=[1, 4], num_nodes=2592, x=[2592, 1], edge_attr=[5141, 2])
# 419 Data(edge_index=[2, 3588], y=0, label=[1, 4], num_nodes=1838, x=[1838, 1], edge_attr=[3588, 2])
# 420 Data(edge_index=[2, 192015], y=0, label=[1, 4], num_nodes=4267, x=[4267, 1], edge_attr=[192015, 2])
# 421 Data(edge_index=[2, 33316], y=0, label=[1, 4], num_nodes=4835, x=[4835, 1], edge_attr=[33316, 2])
# 422 Data(edge_index=[2, 108872], y=1, label=[1, 4], num_nodes=1979, x=[1979, 1], edge_attr=[108872, 2])
# 423 Data(edge_index=[2, 6468], y=0, label=[1, 4], num_nodes=3269, x=[3269, 1], edge_attr=[6468, 2])
# 424 Data(edge_index=[2, 173439], y=0, label=[1, 4], num_nodes=2675, x=[2675, 1], edge_attr=[173439, 2])
# 425 Data(edge_index=[2, 158186], y=0, label=[1, 4], num_nodes=1425, x=[1425, 1], edge_attr=[158186, 2])
# 426 Data(edge_index=[2, 9257], y=0, label=[1, 4], num_nodes=4708, x=[4708, 1], edge_attr=[9257, 2])
# 427 Data(edge_index=[2, 128800], y=0, label=[1, 4], num_nodes=2576, x=[2576, 1], edge_attr=[128800, 2])
# 428 Data(edge_index=[2, 179410], y=0, label=[1, 4], num_nodes=1631, x=[1631, 1], edge_attr=[179410, 2])
# 429 Data(edge_index=[2, 75969], y=0, label=[1, 4], num_nodes=2335, x=[2335, 1], edge_attr=[75969, 2])
# 430 Data(edge_index=[2, 25055], y=0, label=[1, 4], num_nodes=5011, x=[5011, 1], edge_attr=[25055, 2])
# 431 Data(edge_index=[2, 4038], y=0, label=[1, 4], num_nodes=2023, x=[2023, 1], edge_attr=[4038, 2])
# 432 Data(edge_index=[2, 39424], y=0, label=[1, 4], num_nodes=2816, x=[2816, 1], edge_attr=[39424, 2])
# 433 Data(edge_index=[2, 27138], y=0, label=[1, 4], num_nodes=299, x=[299, 1], edge_attr=[27138, 2])
# 434 Data(edge_index=[2, 4580], y=0, label=[1, 4], num_nodes=2306, x=[2306, 1], edge_attr=[4580, 2])
# 435 Data(edge_index=[2, 29334], y=0, label=[1, 4], num_nodes=4889, x=[4889, 1], edge_attr=[29334, 2])
# 436 Data(edge_index=[2, 104645], y=0, label=[1, 4], num_nodes=2451, x=[2451, 1], edge_attr=[104645, 2])
# 437 Data(edge_index=[2, 8828], y=0, label=[1, 4], num_nodes=4430, x=[4430, 1], edge_attr=[8828, 2])
# 438 Data(edge_index=[2, 103375], y=0, label=[1, 4], num_nodes=4135, x=[4135, 1], edge_attr=[103375, 2])
# 439 Data(edge_index=[2, 200460], y=0, label=[1, 4], num_nodes=780, x=[780, 1], edge_attr=[200460, 2])
# 440 Data(edge_index=[2, 1106], y=0, label=[1, 4], num_nodes=216, x=[216, 1], edge_attr=[1106, 2])
# 441 Data(edge_index=[2, 97551], y=0, label=[1, 4], num_nodes=3613, x=[3613, 1], edge_attr=[97551, 2])
# 442 Data(edge_index=[2, 8270], y=2, label=[1, 4], num_nodes=4146, x=[4146, 1], edge_attr=[8270, 2])
# 443 Data(edge_index=[2, 99695], y=0, label=[1, 4], num_nodes=2313, x=[2313, 1], edge_attr=[99695, 2])
# 444 Data(edge_index=[2, 104025], y=0, label=[1, 4], num_nodes=4161, x=[4161, 1], edge_attr=[104025, 2])
# 445 Data(edge_index=[2, 15516], y=0, label=[1, 4], num_nodes=640, x=[640, 1], edge_attr=[15516, 2])
# 446 Data(edge_index=[2, 9643], y=0, label=[1, 4], num_nodes=4850, x=[4850, 1], edge_attr=[9643, 2])
# 447 Data(edge_index=[2, 117536], y=0, label=[1, 4], num_nodes=3673, x=[3673, 1], edge_attr=[117536, 2])
# 448 Data(edge_index=[2, 17828], y=0, label=[1, 4], num_nodes=2853, x=[2853, 1], edge_attr=[17828, 2])
# 449 Data(edge_index=[2, 4990], y=0, label=[1, 4], num_nodes=178, x=[178, 1], edge_attr=[4990, 2])
# 450 Data(edge_index=[2, 16564], y=0, label=[1, 4], num_nodes=492, x=[492, 1], edge_attr=[16564, 2])
# 451 Data(edge_index=[2, 8548], y=0, label=[1, 4], num_nodes=4325, x=[4325, 1], edge_attr=[8548, 2])
# 452 Data(edge_index=[2, 138602], y=0, label=[1, 4], num_nodes=1742, x=[1742, 1], edge_attr=[138602, 2])
# 453 Data(edge_index=[2, 42009], y=0, label=[1, 4], num_nodes=744, x=[744, 1], edge_attr=[42009, 2])
# 454 Data(edge_index=[2, 20365], y=0, label=[1, 4], num_nodes=4073, x=[4073, 1], edge_attr=[20365, 2])
# 455 Data(edge_index=[2, 133937], y=0, label=[1, 4], num_nodes=4005, x=[4005, 1], edge_attr=[133937, 2])
# 456 Data(edge_index=[2, 74918], y=0, label=[1, 4], num_nodes=3273, x=[3273, 1], edge_attr=[74918, 2])
# 457 Data(edge_index=[2, 196150], y=0, label=[1, 4], num_nodes=3048, x=[3048, 1], edge_attr=[196150, 2])
# 458 Data(edge_index=[2, 4351], y=0, label=[1, 4], num_nodes=228, x=[228, 1], edge_attr=[4351, 2])
# 459 Data(edge_index=[2, 49989], y=0, label=[1, 4], num_nodes=4188, x=[4188, 1], edge_attr=[49989, 2])
# 460 Data(edge_index=[2, 6212], y=0, label=[1, 4], num_nodes=3113, x=[3113, 1], edge_attr=[6212, 2])
# 461 Data(edge_index=[2, 30514], y=0, label=[1, 4], num_nodes=1387, x=[1387, 1], edge_attr=[30514, 2])
# 462 Data(edge_index=[2, 61393], y=0, label=[1, 4], num_nodes=841, x=[841, 1], edge_attr=[61393, 2])
# 463 Data(edge_index=[2, 31247], y=1, label=[1, 4], num_nodes=3557, x=[3557, 1], edge_attr=[31247, 2])
# 464 Data(edge_index=[2, 129420], y=0, label=[1, 4], num_nodes=2876, x=[2876, 1], edge_attr=[129420, 2])
# 465 Data(edge_index=[2, 198722], y=0, label=[1, 4], num_nodes=894, x=[894, 1], edge_attr=[198722, 2])
# 466 Data(edge_index=[2, 32124], y=1, label=[1, 4], num_nodes=1072, x=[1072, 1], edge_attr=[32124, 2])
# 467 Data(edge_index=[2, 106224], y=0, label=[1, 4], num_nodes=1127, x=[1127, 1], edge_attr=[106224, 2])
# 468 Data(edge_index=[2, 159613], y=1, label=[1, 4], num_nodes=3851, x=[3851, 1], edge_attr=[159613, 2])
# 469 Data(edge_index=[2, 45494], y=0, label=[1, 4], num_nodes=529, x=[529, 1], edge_attr=[45494, 2])
# 470 Data(edge_index=[2, 101843], y=0, label=[1, 4], num_nodes=4885, x=[4885, 1], edge_attr=[101843, 2])
# ...
# 504 Data(edge_index=[2, 178496], y=0, label=[1, 4], num_nodes=2586, x=[2586, 1], edge_attr=[178496, 2])
# 505 Data(edge_index=[2, 67868], y=0, label=[1, 4], num_nodes=1786, x=[1786, 1], edge_attr=[67868, 2])
# 506 Data(edge_index=[2, 145483], y=0, label=[1, 4], num_nodes=4693, x=[4693, 1], edge_attr=[145483, 2])
# 507 Data(edge_index=[2, 195184], y=0, label=[1, 4], num_nodes=1648, x=[1648, 1], edge_attr=[195184, 2])
# 508 Data(edge_index=[2, 78639], y=1, label=[1, 4], num_nodes=3451, x=[3451, 1], edge_attr=[78639, 2])
# 509 Data(edge_index=[2, 9258], y=0, label=[1, 4], num_nodes=4642, x=[4642, 1], edge_attr=[9258, 2])
# 510 Data(edge_index=[2, 5738], y=3, label=[1, 4], num_nodes=2883, x=[2883, 1], edge_attr=[5738, 2])
# 511 Data(edge_index=[2, 31990], y=0, label=[1, 4], num_nodes=3199, x=[3199, 1], edge_attr=[31990, 2])
# 512 Data(edge_index=[2, 78452], y=0, label=[1, 4], num_nodes=3566, x=[3566, 1], edge_attr=[78452, 2])
# 513 Data(edge_index=[2, 106340], y=0, label=[1, 4], num_nodes=893, x=[893, 1], edge_attr=[106340, 2])
# 514 Data(edge_index=[2, 10623], y=1, label=[1, 4], num_nodes=1899, x=[1899, 1], edge_attr=[10623, 2])
# 515 Data(edge_index=[2, 4821], y=0, label=[1, 4], num_nodes=1403, x=[1403, 1], edge_attr=[4821, 2])
# 516 Data(edge_index=[2, 9005], y=0, label=[1, 4], num_nodes=4534, x=[4534, 1], edge_attr=[9005, 2])
# 517 Data(edge_index=[2, 43731], y=0, label=[1, 4], num_nodes=1173, x=[1173, 1], edge_attr=[43731, 2])
# 518 Data(edge_index=[2, 35088], y=0, label=[1, 4], num_nodes=408, x=[408, 1], edge_attr=[35088, 2])
# 519 Data(edge_index=[2, 71778], y=0, label=[1, 4], num_nodes=4165, x=[4165, 1], edge_attr=[71778, 2])
# 520 Data(edge_index=[2, 46104], y=0, label=[1, 4], num_nodes=1921, x=[1921, 1], edge_attr=[46104, 2])
# 521 Data(edge_index=[2, 14130], y=0, label=[1, 4], num_nodes=311, x=[311, 1], edge_attr=[14130, 2])
# 522 Data(edge_index=[2, 85953], y=0, label=[1, 4], num_nodes=4093, x=[4093, 1], edge_attr=[85953, 2])
# 523 Data(edge_index=[2, 123700], y=0, label=[1, 4], num_nodes=3632, x=[3632, 1], edge_attr=[123700, 2])
# 524 Data(edge_index=[2, 75766], y=0, label=[1, 4], num_nodes=881, x=[881, 1], edge_attr=[75766, 2])
# 525 Data(edge_index=[2, 3596], y=0, label=[1, 4], num_nodes=1826, x=[1826, 1], edge_attr=[3596, 2])
# 526 Data(edge_index=[2, 3691], y=0, label=[1, 4], num_nodes=1862, x=[1862, 1], edge_attr=[3691, 2])
# 527 Data(edge_index=[2, 189504], y=0, label=[1, 4], num_nodes=4032, x=[4032, 1], edge_attr=[189504, 2])
# 528 Data(edge_index=[2, 167915], y=0, label=[1, 4], num_nodes=781, x=[781, 1], edge_attr=[167915, 2])
# 529 Data(edge_index=[2, 131072], y=0, label=[1, 4], num_nodes=4096, x=[4096, 1], edge_attr=[131072, 2])
# 530 Data(edge_index=[2, 85979], y=0, label=[1, 4], num_nodes=1519, x=[1519, 1], edge_attr=[85979, 2])
# 531 Data(edge_index=[2, 8292], y=0, label=[1, 4], num_nodes=4162, x=[4162, 1], edge_attr=[8292, 2])
# 532 Data(edge_index=[2, 163587], y=0, label=[1, 4], num_nodes=4697, x=[4697, 1], edge_attr=[163587, 2])
# 533 Data(edge_index=[2, 98951], y=0, label=[1, 4], num_nodes=1164, x=[1164, 1], edge_attr=[98951, 2])
# 534 Data(edge_index=[2, 106477], y=1, label=[1, 4], num_nodes=1831, x=[1831, 1], edge_attr=[106477, 2])
# 535 Data(edge_index=[2, 64260], y=0, label=[1, 4], num_nodes=3213, x=[3213, 1], edge_attr=[64260, 2])
# 536 Data(edge_index=[2, 3112], y=0, label=[1, 4], num_nodes=1577, x=[1577, 1], edge_attr=[3112, 2])
# 537 Data(edge_index=[2, 81871], y=0, label=[1, 4], num_nodes=2641, x=[2641, 1], edge_attr=[81871, 2])
# 538 Data(edge_index=[2, 30195], y=0, label=[1, 4], num_nodes=3355, x=[3355, 1], edge_attr=[30195, 2])
# 539 Data(edge_index=[2, 5068], y=0, label=[1, 4], num_nodes=502, x=[502, 1], edge_attr=[5068, 2])
# 540 Data(edge_index=[2, 1823], y=0, label=[1, 4], num_nodes=922, x=[922, 1], edge_attr=[1823, 2])
# 541 Data(edge_index=[2, 156632], y=0, label=[1, 4], num_nodes=1688, x=[1688, 1], edge_attr=[156632, 2])
# 542 Data(edge_index=[2, 194852], y=0, label=[1, 4], num_nodes=4487, x=[4487, 1], edge_attr=[194852, 2])
# 543 Data(edge_index=[2, 58630], y=0, label=[1, 4], num_nodes=2255, x=[2255, 1], edge_attr=[58630, 2])
# 544 Data(edge_index=[2, 4489], y=0, label=[1, 4], num_nodes=2282, x=[2282, 1], edge_attr=[4489, 2])
# 545 Data(edge_index=[2, 24650], y=0, label=[1, 4], num_nodes=4930, x=[4930, 1], edge_attr=[24650, 2])
# 546 Data(edge_index=[2, 8684], y=0, label=[1, 4], num_nodes=3816, x=[3816, 1], edge_attr=[8684, 2])
# 547 Data(edge_index=[2, 5440], y=0, label=[1, 4], num_nodes=2774, x=[2774, 1], edge_attr=[5440, 2])
# 548 Data(edge_index=[2, 33057], y=0, label=[1, 4], num_nodes=3673, x=[3673, 1], edge_attr=[33057, 2])
# 549 Data(edge_index=[2, 95663], y=0, label=[1, 4], num_nodes=1147, x=[1147, 1], edge_attr=[95663, 2])
# 550 Data(edge_index=[2, 124267], y=0, label=[1, 4], num_nodes=1698, x=[1698, 1], edge_attr=[124267, 2])
# 551 Data(edge_index=[2, 155734], y=0, label=[1, 4], num_nodes=2679, x=[2679, 1], edge_attr=[155734, 2])
# 552 Data(edge_index=[2, 167868], y=0, label=[1, 4], num_nodes=4663, x=[4663, 1], edge_attr=[167868, 2])
# 553 Data(edge_index=[2, 158613], y=0, label=[1, 4], num_nodes=4067, x=[4067, 1], edge_attr=[158613, 2])
# 554 Data(edge_index=[2, 62261], y=0, label=[1, 4], num_nodes=1525, x=[1525, 1], edge_attr=[62261, 2])
# 555 Data(edge_index=[2, 131708], y=0, label=[1, 4], num_nodes=3466, x=[3466, 1], edge_attr=[131708, 2])
# 556 Data(edge_index=[2, 133429], y=0, label=[1, 4], num_nodes=3103, x=[3103, 1], edge_attr=[133429, 2])
# 557 Data(edge_index=[2, 3596], y=0, label=[1, 4], num_nodes=1826, x=[1826, 1], edge_attr=[3596, 2])
# 558 Data(edge_index=[2, 41469], y=0, label=[1, 4], num_nodes=1413, x=[1413, 1], edge_attr=[41469, 2])
# 559 Data(edge_index=[2, 96432], y=0, label=[1, 4], num_nodes=3444, x=[3444, 1], edge_attr=[96432, 2])
# 560 Data(edge_index=[2, 5254], y=0, label=[1, 4], num_nodes=2642, x=[2642, 1], edge_attr=[5254, 2])
# 561 Data(edge_index=[2, 77390], y=0, label=[1, 4], num_nodes=4375, x=[4375, 1], edge_attr=[77390, 2])
# 562 Data(edge_index=[2, 6402], y=0, label=[1, 4], num_nodes=3242, x=[3242, 1], edge_attr=[6402, 2])
# 563 Data(edge_index=[2, 46420], y=0, label=[1, 4], num_nodes=4642, x=[4642, 1], edge_attr=[46420, 2])
# 564 Data(edge_index=[2, 7493], y=0, label=[1, 4], num_nodes=3754, x=[3754, 1], edge_attr=[7493, 2])
# 565 Data(edge_index=[2, 193922], y=0, label=[1, 4], num_nodes=4126, x=[4126, 1], edge_attr=[193922, 2])
# 566 Data(edge_index=[2, 6923], y=0, label=[1, 4], num_nodes=3500, x=[3500, 1], edge_attr=[6923, 2])
# 567 Data(edge_index=[2, 61017], y=0, label=[1, 4], num_nodes=1849, x=[1849, 1], edge_attr=[61017, 2])
# 568 Data(edge_index=[2, 8208], y=0, label=[1, 4], num_nodes=4177, x=[4177, 1], edge_attr=[8208, 2])
# 569 Data(edge_index=[2, 4899], y=2, label=[1, 4], num_nodes=2452, x=[2452, 1], edge_attr=[4899, 2])
# 570 Data(edge_index=[2, 196262], y=0, label=[1, 4], num_nodes=811, x=[811, 1], edge_attr=[196262, 2])
# 571 Data(edge_index=[2, 9218], y=0, label=[1, 4], num_nodes=527, x=[527, 1], edge_attr=[9218, 2])
# 572 Data(edge_index=[2, 58249], y=1, label=[1, 4], num_nodes=4697, x=[4697, 1], edge_attr=[58249, 2])
# 573 Data(edge_index=[2, 186352], y=1, label=[1, 4], num_nodes=2720, x=[2720, 1], edge_attr=[186352, 2])
# 574 Data(edge_index=[2, 5398], y=0, label=[1, 4], num_nodes=2711, x=[2711, 1], edge_attr=[5398, 2])
# 575 Data(edge_index=[2, 140877], y=0, label=[1, 4], num_nodes=4269, x=[4269, 1], edge_attr=[140877, 2])
# 576 Data(edge_index=[2, 163920], y=0, label=[1, 4], num_nodes=3494, x=[3494, 1], edge_attr=[163920, 2])
# 577 Data(edge_index=[2, 112443], y=0, label=[1, 4], num_nodes=3039, x=[3039, 1], edge_attr=[112443, 2])
# 578 Data(edge_index=[2, 144935], y=0, label=[1, 4], num_nodes=4141, x=[4141, 1], edge_attr=[144935, 2])
# 579 Data(edge_index=[2, 60918], y=0, label=[1, 4], num_nodes=4252, x=[4252, 1], edge_attr=[60918, 2])
# 580 Data(edge_index=[2, 6871], y=0, label=[1, 4], num_nodes=3452, x=[3452, 1], edge_attr=[6871, 2])
# 581 Data(edge_index=[2, 23502], y=0, label=[1, 4], num_nodes=698, x=[698, 1], edge_attr=[23502, 2])
# 582 Data(edge_index=[2, 136260], y=1, label=[1, 4], num_nodes=1304, x=[1304, 1], edge_attr=[136260, 2])
# 583 Data(edge_index=[2, 32676], y=0, label=[1, 4], num_nodes=1556, x=[1556, 1], edge_attr=[32676, 2])
# 584 Data(edge_index=[2, 75872], y=0, label=[1, 4], num_nodes=2371, x=[2371, 1], edge_attr=[75872, 2])
# 585 Data(edge_index=[2, 97668], y=0, label=[1, 4], num_nodes=4191, x=[4191, 1], edge_attr=[97668, 2])
# 586 Data(edge_index=[2, 110246], y=0, label=[1, 4], num_nodes=4376, x=[4376, 1], edge_attr=[110246, 2])
# 587 Data(edge_index=[2, 8984], y=0, label=[1, 4], num_nodes=1763, x=[1763, 1], edge_attr=[8984, 2])
# 588 Data(edge_index=[2, 198990], y=0, label=[1, 4], num_nodes=1809, x=[1809, 1], edge_attr=[198990, 2])
# 589 Data(edge_index=[2, 4322], y=0, label=[1, 4], num_nodes=2178, x=[2178, 1], edge_attr=[4322, 2])
# 590 Data(edge_index=[2, 17711], y=0, label=[1, 4], num_nodes=199, x=[199, 1], edge_attr=[17711, 2])
# 591 Data(edge_index=[2, 127802], y=0, label=[1, 4], num_nodes=1505, x=[1505, 1], edge_attr=[127802, 2])
# 592 Data(edge_index=[2, 105972], y=0, label=[1, 4], num_nodes=3055, x=[3055, 1], edge_attr=[105972, 2])
# 593 Data(edge_index=[2, 3554], y=0, label=[1, 4], num_nodes=1850, x=[1850, 1], edge_attr=[3554, 2])
# 594 Data(edge_index=[2, 175868], y=0, label=[1, 4], num_nodes=3997, x=[3997, 1], edge_attr=[175868, 2])
# 595 Data(edge_index=[2, 3295], y=0, label=[1, 4], num_nodes=659, x=[659, 1], edge_attr=[3295, 2])
# 596 Data(edge_index=[2, 123331], y=0, label=[1, 4], num_nodes=1524, x=[1524, 1], edge_attr=[123331, 2])
# 597 Data(edge_index=[2, 175536], y=0, label=[1, 4], num_nodes=4876, x=[4876, 1], edge_attr=[175536, 2])
# 598 Data(edge_index=[2, 127048], y=0, label=[1, 4], num_nodes=2370, x=[2370, 1], edge_attr=[127048, 2])
# 599 Data(edge_index=[2, 3516], y=0, label=[1, 4], num_nodes=1762, x=[1762, 1], edge_attr=[3516, 2])
# 600 Data(edge_index=[2, 109653], y=1, label=[1, 4], num_nodes=1229, x=[1229, 1], edge_attr=[109653, 2])
# 601 Data(edge_index=[2, 94446], y=0, label=[1, 4], num_nodes=4293, x=[4293, 1], edge_attr=[94446, 2])
# 602 Data(edge_index=[2, 89801], y=0, label=[1, 4], num_nodes=1564, x=[1564, 1], edge_attr=[89801, 2])
# 603 Data(edge_index=[2, 137376], y=0, label=[1, 4], num_nodes=859, x=[859, 1], edge_attr=[137376, 2])
# 604 Data(edge_index=[2, 88315], y=0, label=[1, 4], num_nodes=1815, x=[1815, 1], edge_attr=[88315, 2])
# 605 Data(edge_index=[2, 5438], y=0, label=[1, 4], num_nodes=2730, x=[2730, 1], edge_attr=[5438, 2])
# 606 Data(edge_index=[2, 40233], y=1, label=[1, 4], num_nodes=3982, x=[3982, 1], edge_attr=[40233, 2])
# 607 Data(edge_index=[2, 114635], y=0, label=[1, 4], num_nodes=2595, x=[2595, 1], edge_attr=[114635, 2])
# 608 Data(edge_index=[2, 180939], y=0, label=[1, 4], num_nodes=3768, x=[3768, 1], edge_attr=[180939, 2])
# 609 Data(edge_index=[2, 64446], y=1, label=[1, 4], num_nodes=4085, x=[4085, 1], edge_attr=[64446, 2])
# 610 Data(edge_index=[2, 155980], y=0, label=[1, 4], num_nodes=2836, x=[2836, 1], edge_attr=[155980, 2])
# 611 Data(edge_index=[2, 64452], y=0, label=[1, 4], num_nodes=1977, x=[1977, 1], edge_attr=[64452, 2])
# 612 Data(edge_index=[2, 9286], y=0, label=[1, 4], num_nodes=4727, x=[4727, 1], edge_attr=[9286, 2])
# 613 Data(edge_index=[2, 171534], y=0, label=[1, 4], num_nodes=2486, x=[2486, 1], edge_attr=[171534, 2])
# 614 Data(edge_index=[2, 96868], y=0, label=[1, 4], num_nodes=397, x=[397, 1], edge_attr=[96868, 2])
# 615 Data(edge_index=[2, 21956], y=0, label=[1, 4], num_nodes=4687, x=[4687, 1], edge_attr=[21956, 2])
# 616 Data(edge_index=[2, 9045], y=0, label=[1, 4], num_nodes=1143, x=[1143, 1], edge_attr=[9045, 2])
# 617 Data(edge_index=[2, 107626], y=0, label=[1, 4], num_nodes=4878, x=[4878, 1], edge_attr=[107626, 2])
# 618 Data(edge_index=[2, 161449], y=0, label=[1, 4], num_nodes=4847, x=[4847, 1], edge_attr=[161449, 2])
# 619 Data(edge_index=[2, 68764], y=0, label=[1, 4], num_nodes=1913, x=[1913, 1], edge_attr=[68764, 2])
# 620 Data(edge_index=[2, 175084], y=0, label=[1, 4], num_nodes=3367, x=[3367, 1], edge_attr=[175084, 2])
# 621 Data(edge_index=[2, 91202], y=0, label=[1, 4], num_nodes=4832, x=[4832, 1], edge_attr=[91202, 2])
# 622 Data(edge_index=[2, 162492], y=0, label=[1, 4], num_nodes=2497, x=[2497, 1], edge_attr=[162492, 2])
# 623 Data(edge_index=[2, 53105], y=0, label=[1, 4], num_nodes=4222, x=[4222, 1], edge_attr=[53105, 2])
# 624 Data(edge_index=[2, 55573], y=0, label=[1, 4], num_nodes=3269, x=[3269, 1], edge_attr=[55573, 2])
# 625 Data(edge_index=[2, 105659], y=0, label=[1, 4], num_nodes=3298, x=[3298, 1], edge_attr=[105659, 2])
# 626 Data(edge_index=[2, 59010], y=0, label=[1, 4], num_nodes=4215, x=[4215, 1], edge_attr=[59010, 2])
# 627 Data(edge_index=[2, 189625], y=1, label=[1, 4], num_nodes=2138, x=[2138, 1], edge_attr=[189625, 2])
# 628 Data(edge_index=[2, 192178], y=0, label=[1, 4], num_nodes=1961, x=[1961, 1], edge_attr=[192178, 2])
# 629 Data(edge_index=[2, 175826], y=0, label=[1, 4], num_nodes=4914, x=[4914, 1], edge_attr=[175826, 2])
# 630 Data(edge_index=[2, 24982], y=0, label=[1, 4], num_nodes=3320, x=[3320, 1], edge_attr=[24982, 2])
# 631 Data(edge_index=[2, 128535], y=0, label=[1, 4], num_nodes=3440, x=[3440, 1], edge_attr=[128535, 2])
# 632 Data(edge_index=[2, 176750], y=1, label=[1, 4], num_nodes=3320, x=[3320, 1], edge_attr=[176750, 2])
# 633 Data(edge_index=[2, 26172], y=0, label=[1, 4], num_nodes=2181, x=[2181, 1], edge_attr=[26172, 2])
# 634 Data(edge_index=[2, 8218], y=0, label=[1, 4], num_nodes=4130, x=[4130, 1], edge_attr=[8218, 2])
# 635 Data(edge_index=[2, 161103], y=0, label=[1, 4], num_nodes=647, x=[647, 1], edge_attr=[161103, 2])
# 636 Data(edge_index=[2, 173007], y=0, label=[1, 4], num_nodes=4359, x=[4359, 1], edge_attr=[173007, 2])
# 637 Data(edge_index=[2, 3684], y=0, label=[1, 4], num_nodes=1865, x=[1865, 1], edge_attr=[3684, 2])
# 638 Data(edge_index=[2, 125669], y=0, label=[1, 4], num_nodes=3971, x=[3971, 1], edge_attr=[125669, 2])
# 639 Data(edge_index=[2, 1298], y=0, label=[1, 4], num_nodes=121, x=[121, 1], edge_attr=[1298, 2])
# 640 Data(edge_index=[2, 26937], y=0, label=[1, 4], num_nodes=2993, x=[2993, 1], edge_attr=[26937, 2])
# 641 Data(edge_index=[2, 6642], y=0, label=[1, 4], num_nodes=1027, x=[1027, 1], edge_attr=[6642, 2])
# 642 Data(edge_index=[2, 126695], y=0, label=[1, 4], num_nodes=2222, x=[2222, 1], edge_attr=[126695, 2])
# 643 Data(edge_index=[2, 149978], y=0, label=[1, 4], num_nodes=2492, x=[2492, 1], edge_attr=[149978, 2])
# 644 Data(edge_index=[2, 83809], y=0, label=[1, 4], num_nodes=4411, x=[4411, 1], edge_attr=[83809, 2])
# 645 Data(edge_index=[2, 104934], y=1, label=[1, 4], num_nodes=1401, x=[1401, 1], edge_attr=[104934, 2])
# 646 Data(edge_index=[2, 133546], y=2, label=[1, 4], num_nodes=4062, x=[4062, 1], edge_attr=[133546, 2])
# 647 Data(edge_index=[2, 46600], y=0, label=[1, 4], num_nodes=1338, x=[1338, 1], edge_attr=[46600, 2])
# 648 Data(edge_index=[2, 5253], y=0, label=[1, 4], num_nodes=2662, x=[2662, 1], edge_attr=[5253, 2])
# 649 Data(edge_index=[2, 119930], y=0, label=[1, 4], num_nodes=3247, x=[3247, 1], edge_attr=[119930, 2])
# 650 Data(edge_index=[2, 39820], y=0, label=[1, 4], num_nodes=1810, x=[1810, 1], edge_attr=[39820, 2])
# 651 Data(edge_index=[2, 174887], y=0, label=[1, 4], num_nodes=3721, x=[3721, 1], edge_attr=[174887, 2])
# 652 Data(edge_index=[2, 9172], y=0, label=[1, 4], num_nodes=4622, x=[4622, 1], edge_attr=[9172, 2])
# 653 Data(edge_index=[2, 34914], y=0, label=[1, 4], num_nodes=1587, x=[1587, 1], edge_attr=[34914, 2])
# 654 Data(edge_index=[2, 180480], y=0, label=[1, 4], num_nodes=1504, x=[1504, 1], edge_attr=[180480, 2])
# 655 Data(edge_index=[2, 155643], y=0, label=[1, 4], num_nodes=1789, x=[1789, 1], edge_attr=[155643, 2])
# 656 Data(edge_index=[2, 115320], y=0, label=[1, 4], num_nodes=1240, x=[1240, 1], edge_attr=[115320, 2])
# 657 Data(edge_index=[2, 9006], y=0, label=[1, 4], num_nodes=4538, x=[4538, 1], edge_attr=[9006, 2])
# 658 Data(edge_index=[2, 177150], y=1, label=[1, 4], num_nodes=2065, x=[2065, 1], edge_attr=[177150, 2])
# 1.6239995956420898
# Avg. nodes 2657.7238239757207
# Avg. edges 79028.33232169955

# %%
import numpy as np
ys = np.array(ys)
x = [sum(ys == i) for i in range(4)]
print(np.array(x)/np.sum(x))
# Out:
# [0.87556904 0.10318665 0.01213961 0.0091047 ]

# %%
gains = []
min_runtimes = []
for runtime_vec in runtimes:
    sorted_runtime_vec = sorted(runtime_vec[0])
    min_runtimes.append(sorted_runtime_vec[0])
    gains.append(sorted_runtime_vec[1] - sorted_runtime_vec[0])
gains = np.array(gains)
print(np.min(gains), np.percentile(gains, 25), np.percentile(gains, 50), np.percentile(gains, 75), np.max(gains))
print(np.mean(min_runtimes))
# Out:
# 0.0 16436.363636363636 86000.0 213500.0 4078000.0
# 119621.54668890814

# %% [markdown]
# |Name|Graphs|Classes|Avg. Nodes|Avg. Edges|Node Labels|Edge Labels|Node Attr.|Edge Attr.|Geometry|
# |---|---|---|---|---|---|---|---|---|---|
# |MCFSmall|659|4|2658|79028|-|-| +(1)| +(2)| - |
